# %%
import mido
import numpy as np
import matplotlib.pyplot as plt
import PreProcessor as pp

# %%
dataset = pp.load_dataset("adl-piano-midi")
ClassicSongs = pp.files_to_songs(dataset["Classical"])

channel_to_ind, ind_to_channel, note_to_ind, ind_to_note = pp.dicts_from_songs(ClassicSongs)
velocity_range, tick_range = pp.ranges_from_songs(ClassicSongs)

n_Channels = len(channel_to_ind)
n_Notes = len(note_to_ind)

print("Number of channels  :",n_Channels,"\nNumber of notes     :",n_Notes,"\nVelocity range      :",velocity_range[0],velocity_range[1],"\nTime ticks range    :",tick_range[0],tick_range[1])
# Out:
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Alexander Borodin\Nocturne.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Antonio Salieri\Invention.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Bela Bartok\Andante.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Bela Bartok\Romanian Folk Dance.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Claude Debussy\Clair De Lune.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Franz Schubert\Impromptu in C-Moll.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Franz Schubert\Impromptu in Ges-dur.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Franz Schubert\Trois Marches militaires 3.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Frederic Chopin\Prelude Op 28 No7.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Giacomo Puccini\O Mio Babibino Caro.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Jean-Baptiste Lully\Minuet.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Johann Sebastian Bach\Aria, BWV 515.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Johann Sebastian Bach\Aus meines Herzens Grunde (Chorale 1).mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Johann Sebastian Bach\English Suite 3 Gavotte.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Johann Sebastian Bach\Gib dich zufrieden und sei stille.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Johann Sebastian Bach\Invention 1, BWV 772.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Johann Sebastian Bach\Invention 5.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Johann Sebastian Bach\Invention 6.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Johann Sebastian Bach\Invention No 8.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Johann Sebastian Bach\Sleepers, Wake.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Ludwig van Beethoven\Moonlight Sonata 1st movement.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Ludwig van Beethoven\Moonlight Sonata 3rd Movement.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Ludwig van Beethoven\Sonata for Piano with Horn, Op 17.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Pyotr Ilyich Tchaikovsky\July - Song of the Reaper.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Pyotr Ilyich Tchaikovsky\March - Song of the Lark.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Pyotr Ilyich Tchaikovsky\Nutcracker Minature Overture.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Richard Wagner\Bridal March.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Richard Wagner\Ride of the Valkyries.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Robert Schumann\Curious Story.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Wolfgang Amadeus Mozart\Clarinet Concerto Theme.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Wolfgang Amadeus Mozart\Minuet from Don Juan.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Classical\Wolfgang Amadeus Mozart\Theme from C K467.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\German Baroque\Johann Krieger\Minuet.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Late Romantic Era\Charles-Valentin Alkan\Prélude.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Late Romantic Era\Charles-Valentin Alkan\Saltarelle.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Neo-Classical\Ludovico Einaudi\Divenire.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Neo-Classical\Yiruma\Rivers Flow in You.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Operatic Pop\Yanni\Hijo de la Luna.mid
# Couldn't load : adl-piano-midi\adl-piano-midi\Classical\Post-Romantic Era\Vladimir Rebikov\The Bear.mid
# Number of channels  : 12
# Number of notes     : 105
# Velocity range      : 0 127
# Time ticks range    : 0.0 190.285

# %%
AllChannels = np.array([])
AllNotes = np.array([])
AllVelocities = np.array([])
AllTicks = np.array([])
for song in ClassicSongs.values():
    AllChannels = np.append(AllChannels,song[:,0])
    AllNotes = np.append(AllNotes,song[:,1])
    AllVelocities = np.append(AllVelocities,song[:,2])
    AllTicks = np.append(AllTicks,song[:,3])

OneHotChannels = pp.one_hot_encode(channel_to_ind,AllChannels)
OneHotNotes = pp.one_hot_encode(note_to_ind,AllNotes)
AllVelocities = AllVelocities.reshape((-1,1))
AllTicks = AllTicks.reshape((-1,1))

# %%
print(AllTicks.shape)
print(AllChannels.shape)
print(AllNotes.shape)
print(AllVelocities.shape)
# Out:
# (2148125, 1)
# (2148125,)
# (2148125,)
# (2148125, 1)

# %%
seq_length = 30
n_batch = 200

X_channels, y_channels = pp.label_sequences(OneHotChannels,seq_length,n_batch)
X_notes, y_notes = pp.label_sequences(OneHotNotes,seq_length,n_batch)
X_velocities, y_velocities = pp.label_sequences(AllVelocities,seq_length,n_batch)
X_ticks, y_ticks = pp.label_sequences(AllTicks,seq_length,n_batch)
print(X_channels.shape)
print(X_notes.shape)
print(X_velocities.shape)
print(X_ticks.shape)

#X_train = np.concatenate([X_notes, X_velocities], axis=2) #np.concatenate([X_channels, X_notes, X_velocities, X_ticks], axis=2)
#y_train = np.concatenate([y_notes, y_velocities], axis=2) #np.concatenate([y_channels, y_notes, y_velocities, y_ticks], axis=2)
#print(X_train.shape)
#print(y_train.shape)
# Out:
# (71600, 30, 12)
# (71600, 30, 105)
# (71600, 30, 1)
# (71600, 30, 1)

# %%
from keras.models import Model
from tensorflow.keras.layers import Input, SimpleRNN, Dense, Lambda, Softmax, Activation, concatenate, LSTM,GRU
from keras import optimizers
import tensorflow as tf

# %%
def rounded_accuracy(y_true, y_pred):
    y_pred_rounded = tf.round(y_pred)
    correct_predictions = tf.equal(tf.cast(y_pred_rounded, tf.int32), tf.cast(y_true, tf.int32))
    accuracy = tf.reduce_mean(tf.cast(correct_predictions, tf.float32))
    return accuracy

# %%
dim = 300

loss = []
channels_accuracy = []
notes_accuracy = []
velocities_accuracy = []
ticks_accuracy = []

# Define input layers for notes and velocities
input_channels = Input(shape=(None, n_Channels))
input_notes = Input(shape=(None, n_Notes))
input_velocities = Input(shape=(None, 1))
input_ticks = Input(shape=(None, 1))

# Define SimpleRNN layer
rnn_output = SimpleRNN(units=dim, return_sequences=True)(concatenate([input_channels, input_notes, input_velocities, input_ticks]))

# Define Dense layer for each branch
channels_output = Dense(units=n_Channels)(rnn_output)
notes_output = Dense(units=n_Notes)(rnn_output)
velocities_output = Dense(units=1)(rnn_output)
ticks_output = Dense(units=1)(rnn_output)

# Use Lambda layer to split the output of SimpleRNN into two branches
final_channels = Softmax(name="Channels")(channels_output)
final_notes = Softmax(name="Notes")(notes_output)
final_velocities = Lambda(lambda x: (tf.sigmoid(x) * (velocity_range[1] - velocity_range[0]) + velocity_range[0]), name="Velocities")(velocities_output)
final_ticks = Lambda(lambda x: (tf.sigmoid(x) * (tick_range[1] - tick_range[0]) + tick_range[0]), name="Time-Ticks")(ticks_output)

# Define the model with inputs and outputs
model = Model(inputs=[input_channels, input_notes, input_velocities, input_ticks], outputs=[final_channels, final_notes, final_velocities, final_ticks])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, 12)]   0           []
#
#  input_2 (InputLayer)           [(None, None, 105)]  0           []
#
#  input_3 (InputLayer)           [(None, None, 1)]    0           []
#
#  input_4 (InputLayer)           [(None, None, 1)]    0           []
#
#  concatenate (Concatenate)      (None, None, 119)    0           ['input_1[0][0]',
#                                                                   'input_2[0][0]',
#                                                                   'input_3[0][0]',
#                                                                   'input_4[0][0]']
#
#  simple_rnn (SimpleRNN)         (None, None, 300)    126000      ['concatenate[0][0]']
#
#  dense (Dense)                  (None, None, 12)     3612        ['simple_rnn[0][0]']
#
#  dense_1 (Dense)                (None, None, 105)    31605       ['simple_rnn[0][0]']
#
#  dense_2 (Dense)                (None, None, 1)      301         ['simple_rnn[0][0]']
#
#  dense_3 (Dense)                (None, None, 1)      301         ['simple_rnn[0][0]']
#
#  Channels (Softmax)             (None, None, 12)     0           ['dense[0][0]']
#
#  Notes (Softmax)                (None, None, 105)    0           ['dense_1[0][0]']
#
#  Velocities (Lambda)            (None, None, 1)      0           ['dense_2[0][0]']
#
#  Time-Ticks (Lambda)            (None, None, 1)      0           ['dense_3[0][0]']
#
# ==================================================================================================
# Total params: 161,819
# Trainable params: 161,819
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
n_epochs = 15

def rounded_accuracy(y_true, y_pred):
    y_pred_rounded = tf.round(y_pred)
    correct_predictions = tf.equal(tf.cast(y_pred_rounded, tf.int32), tf.cast(y_true, tf.int32))
    accuracy = tf.reduce_mean(tf.cast(correct_predictions, tf.float32))
    return accuracy

losses = {
    'Channels': 'categorical_crossentropy',
    'Notes': 'categorical_crossentropy',
    'Velocities': 'mean_squared_error',
    'Time-Ticks': 'mean_squared_error'
}


loss_weights = {
    'Channels': 0.5,
    'Notes': 5.0,
    'Velocities': 0.02,
    'Time-Ticks': 2e-7
}

metrics = {
    'Channels': 'accuracy',
    'Notes': 'accuracy',
    'Velocities': rounded_accuracy,
    'Time-Ticks': rounded_accuracy
}

model.compile(optimizer='adam', loss=losses, loss_weights=loss_weights, metrics=metrics)
history = model.fit([X_channels, X_notes, X_velocities, X_ticks], [y_channels, y_notes, y_velocities, y_ticks], epochs=n_epochs, batch_size=n_batch)

loss.append(history.history['loss'])
channels_accuracy.append(history.history['Channels_accuracy'])
notes_accuracy.append(history.history['Notes_accuracy'])
velocities_accuracy.append(history.history['Velocities_rounded_accuracy'])
ticks_accuracy.append(history.history['Time-Ticks_rounded_accuracy'])
# Out:
# Epoch 1/20
# 358/358 [==============================] - 56s 135ms/step - loss: 38.3679 - Channels_loss: 0.8031 - Notes_loss: 3.9482 - Velocities_loss: 911.2704 - Time-Ticks_loss: 450.0529 - Channels_accuracy: 0.6799 - Notes_accuracy: 0.0415 - Velocities_rounded_accuracy: 0.0117 - Time-Ticks_rounded_accuracy: 4.3715e-04
# Epoch 2/20
# 358/358 [==============================] - 43s 120ms/step - loss: 34.2633 - Channels_loss: 0.6502 - Notes_loss: 3.8266 - Velocities_loss: 740.2565 - Time-Ticks_loss: 42.7170 - Channels_accuracy: 0.7087 - Notes_accuracy: 0.0622 - Velocities_rounded_accuracy: 0.0098 - Time-Ticks_rounded_accuracy: 0.0408
# Epoch 3/20
# 358/358 [==============================] - 41s 115ms/step - loss: 32.2480 - Channels_loss: 0.5963 - Notes_loss: 3.5123 - Velocities_loss: 719.4312 - Time-Ticks_loss: 24.5824 - Channels_accuracy: 0.7240 - Notes_accuracy: 0.1062 - Velocities_rounded_accuracy: 0.0099 - Time-Ticks_rounded_accuracy: 0.2245
# Epoch 4/20
# 358/358 [==============================] - 49s 137ms/step - loss: 30.8507 - Channels_loss: 0.5646 - Notes_loss: 3.3001 - Velocities_loss: 703.3909 - Time-Ticks_loss: 15.0826 - Channels_accuracy: 0.7334 - Notes_accuracy: 0.1376 - Velocities_rounded_accuracy: 0.0105 - Time-Ticks_rounded_accuracy: 0.3405
# Epoch 5/20
# 358/358 [==============================] - 53s 148ms/step - loss: 30.2290 - Channels_loss: 0.5472 - Notes_loss: 3.2120 - Velocities_loss: 694.7599 - Time-Ticks_loss: 9.7385 - Channels_accuracy: 0.7392 - Notes_accuracy: 0.1514 - Velocities_rounded_accuracy: 0.0105 - Time-Ticks_rounded_accuracy: 0.4354
# Epoch 6/20
# 358/358 [==============================] - 50s 139ms/step - loss: 29.8047 - Channels_loss: 0.5336 - Notes_loss: 3.1614 - Velocities_loss: 686.5453 - Time-Ticks_loss: 6.3962 - Channels_accuracy: 0.7447 - Notes_accuracy: 0.1604 - Velocities_rounded_accuracy: 0.0110 - Time-Ticks_rounded_accuracy: 0.5202
# Epoch 7/20
# 358/358 [==============================] - 56s 156ms/step - loss: 29.5327 - Channels_loss: 0.5238 - Notes_loss: 3.1324 - Velocities_loss: 680.4383 - Time-Ticks_loss: 4.4269 - Channels_accuracy: 0.7496 - Notes_accuracy: 0.1665 - Velocities_rounded_accuracy: 0.0113 - Time-Ticks_rounded_accuracy: 0.5846
# Epoch 8/20
# 358/358 [==============================] - 49s 137ms/step - loss: 29.2730 - Channels_loss: 0.5158 - Notes_loss: 3.1066 - Velocities_loss: 674.0952 - Time-Ticks_loss: 3.1010 - Channels_accuracy: 0.7549 - Notes_accuracy: 0.1724 - Velocities_rounded_accuracy: 0.0124 - Time-Ticks_rounded_accuracy: 0.6687
# Epoch 9/20
# 358/358 [==============================] - 45s 125ms/step - loss: 29.0735 - Channels_loss: 0.5099 - Notes_loss: 3.0882 - Velocities_loss: 668.8718 - Time-Ticks_loss: 2.2639 - Channels_accuracy: 0.7587 - Notes_accuracy: 0.1764 - Velocities_rounded_accuracy: 0.0166 - Time-Ticks_rounded_accuracy: 0.7361
# Epoch 10/20
# 358/358 [==============================] - 50s 138ms/step - loss: 28.9058 - Channels_loss: 0.5057 - Notes_loss: 3.0724 - Velocities_loss: 664.5499 - Time-Ticks_loss: 1.7019 - Channels_accuracy: 0.7622 - Notes_accuracy: 0.1802 - Velocities_rounded_accuracy: 0.0225 - Time-Ticks_rounded_accuracy: 0.7951
# Epoch 11/20
# 358/358 [==============================] - 49s 138ms/step - loss: 28.7567 - Channels_loss: 0.5028 - Notes_loss: 3.0576 - Velocities_loss: 660.8632 - Time-Ticks_loss: 1.3188 - Channels_accuracy: 0.7645 - Notes_accuracy: 0.1836 - Velocities_rounded_accuracy: 0.0319 - Time-Ticks_rounded_accuracy: 0.8280
# Epoch 12/20
# 358/358 [==============================] - 59s 165ms/step - loss: 28.5954 - Channels_loss: 0.5006 - Notes_loss: 3.0435 - Velocities_loss: 656.3932 - Time-Ticks_loss: 1.0272 - Channels_accuracy: 0.7662 - Notes_accuracy: 0.1863 - Velocities_rounded_accuracy: 0.0417 - Time-Ticks_rounded_accuracy: 0.8720
# Epoch 13/20
# 358/358 [==============================] - 55s 153ms/step - loss: 28.4228 - Channels_loss: 0.4965 - Notes_loss: 3.0295 - Velocities_loss: 651.3517 - Time-Ticks_loss: 0.8202 - Channels_accuracy: 0.7687 - Notes_accuracy: 0.1896 - Velocities_rounded_accuracy: 0.0523 - Time-Ticks_rounded_accuracy: 0.8900
# Epoch 14/20
# 358/358 [==============================] - 49s 136ms/step - loss: 28.2882 - Channels_loss: 0.4948 - Notes_loss: 3.0166 - Velocities_loss: 647.8918 - Time-Ticks_loss: 0.6612 - Channels_accuracy: 0.7698 - Notes_accuracy: 0.1922 - Velocities_rounded_accuracy: 0.0737 - Time-Ticks_rounded_accuracy: 0.9092
# Epoch 15/20
# 358/358 [==============================] - 56s 157ms/step - loss: 28.1341 - Channels_loss: 0.4929 - Notes_loss: 3.0057 - Velocities_loss: 642.9457 - Time-Ticks_loss: 0.5273 - Channels_accuracy: 0.7704 - Notes_accuracy: 0.1948 - Velocities_rounded_accuracy: 0.0912 - Time-Ticks_rounded_accuracy: 0.9245
# Epoch 16/20
# 358/358 [==============================] - 55s 154ms/step - loss: 28.0079 - Channels_loss: 0.4907 - Notes_loss: 2.9971 - Velocities_loss: 638.8528 - Time-Ticks_loss: 0.4505 - Channels_accuracy: 0.7722 - Notes_accuracy: 0.1969 - Velocities_rounded_accuracy: 0.1138 - Time-Ticks_rounded_accuracy: 0.9334
# Epoch 17/20
# 358/358 [==============================] - 46s 129ms/step - loss: 27.8939 - Channels_loss: 0.4888 - Notes_loss: 2.9874 - Velocities_loss: 635.6348 - Time-Ticks_loss: 0.3672 - Channels_accuracy: 0.7729 - Notes_accuracy: 0.1990 - Velocities_rounded_accuracy: 0.1242 - Time-Ticks_rounded_accuracy: 0.9432
# Epoch 18/20
# 358/358 [==============================] - 43s 120ms/step - loss: 27.7862 - Channels_loss: 0.4885 - Notes_loss: 2.9803 - Velocities_loss: 632.0312 - Time-Ticks_loss: 0.3122 - Channels_accuracy: 0.7725 - Notes_accuracy: 0.2006 - Velocities_rounded_accuracy: 0.1363 - Time-Ticks_rounded_accuracy: 0.9501
# Epoch 19/20
# 358/358 [==============================] - 39s 109ms/step - loss: 27.6683 - Channels_loss: 0.4860 - Notes_loss: 2.9709 - Velocities_loss: 628.5441 - Time-Ticks_loss: 0.2584 - Channels_accuracy: 0.7741 - Notes_accuracy: 0.2025 - Velocities_rounded_accuracy: 0.1376 - Time-Ticks_rounded_accuracy: 0.9567
# Epoch 20/20
# 358/358 [==============================] - 40s 113ms/step - loss: 27.5740 - Channels_loss: 0.4866 - Notes_loss: 2.9646 - Velocities_loss: 625.3877 - Time-Ticks_loss: 0.2271 - Channels_accuracy: 0.7740 - Notes_accuracy: 0.2039 - Velocities_rounded_accuracy: 0.1522 - Time-Ticks_rounded_accuracy: 0.9608

# %%
##Plotting
plt.figure()
plt.plot(loss[0])
plt.title("Training our Multi-Input Multi-Output RNN")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
##Plot the accuracy
plt.figure()
plt.plot(channels_accuracy[0])
plt.plot(notes_accuracy[0])
plt.plot(velocities_accuracy[0])
plt.plot(ticks_accuracy[0])
plt.title("Accuracy of the four variables")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Channels', 'Notes', 'Velocities', 'Time-Ticks']) 
plt.show()

# %%
##  lstm 
dim = 300

lossLSTM = []
channels_accuracyLSTM = []
notes_accuracyLSTM = []
velocities_accuracyLSTM = []
ticks_accuracyLSTM = []

lstm_output = LSTM(units=dim,return_sequences=True)(concatenate([input_channels, input_notes, input_velocities, input_ticks]))

channels_outputLSTM = Dense(units=n_Channels)(lstm_output)
notes_outputLSTM = Dense(units=n_Notes)(lstm_output)
velocities_outputLSTM = Dense(units=1)(lstm_output)
ticks_outputLSTM = Dense(units=1)(lstm_output)

final_channelsLSTM = Softmax(name="Channels")(channels_outputLSTM)
final_notesLSTM = Softmax(name="Notes")(notes_outputLSTM)
final_velocitiesLSTM = Lambda(lambda x: (tf.sigmoid(x) * (velocity_range[1] - velocity_range[0]) + velocity_range[0]), name="Velocities")(velocities_outputLSTM)
final_ticksLSTM = Lambda(lambda x: (tf.sigmoid(x) * (tick_range[1] - tick_range[0]) + tick_range[0]), name="Time-Ticks")(ticks_outputLSTM)

LSTMmodel = Model(inputs=[input_channels,input_notes,input_velocities,input_ticks],outputs =[final_channelsLSTM,final_notesLSTM,final_velocitiesLSTM,final_ticksLSTM])
LSTMmodel.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, 12)]   0           []
#
#  input_2 (InputLayer)           [(None, None, 105)]  0           []
#
#  input_3 (InputLayer)           [(None, None, 1)]    0           []
#
#  input_4 (InputLayer)           [(None, None, 1)]    0           []
#
#  concatenate_2 (Concatenate)    (None, None, 119)    0           ['input_1[0][0]',
#                                                                   'input_2[0][0]',
#                                                                   'input_3[0][0]',
#                                                                   'input_4[0][0]']
#
#  lstm_1 (LSTM)                  (None, None, 300)    504000      ['concatenate_2[0][0]']
#
#  dense_8 (Dense)                (None, None, 12)     3612        ['lstm_1[0][0]']
#
#  dense_9 (Dense)                (None, None, 105)    31605       ['lstm_1[0][0]']
#
#  dense_10 (Dense)               (None, None, 1)      301         ['lstm_1[0][0]']
#
#  dense_11 (Dense)               (None, None, 1)      301         ['lstm_1[0][0]']
#
#  Channels (Softmax)             (None, None, 12)     0           ['dense_8[0][0]']
#
#  Notes (Softmax)                (None, None, 105)    0           ['dense_9[0][0]']
#
#  Velocities (Lambda)            (None, None, 1)      0           ['dense_10[0][0]']
#
#  Time-Ticks (Lambda)            (None, None, 1)      0           ['dense_11[0][0]']
#
# ==================================================================================================
# Total params: 539,819
# Trainable params: 539,819
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
n_epochs = 13
LSTMmodel.compile(optimizer='adam', loss=losses, loss_weights=loss_weights, metrics=metrics)
historyLSTM = LSTMmodel.fit([X_channels, X_notes, X_velocities, X_ticks], [y_channels, y_notes, y_velocities, y_ticks], epochs=n_epochs, batch_size=n_batch)
# Out:
# Epoch 1/13
# 358/358 [==============================] - 168s 453ms/step - loss: 35.5021 - Channels_loss: 0.7714 - Notes_loss: 3.8613 - Velocities_loss: 790.4778 - Time-Ticks_loss: 435.8419 - Channels_accuracy: 0.6895 - Notes_accuracy: 0.0547 - Velocities_rounded_accuracy: 0.0098 - Time-Ticks_rounded_accuracy: 0.0017
# Epoch 2/13
# 358/358 [==============================] - 160s 447ms/step - loss: 30.8453 - Channels_loss: 0.5684 - Notes_loss: 3.2975 - Velocities_loss: 703.6722 - Time-Ticks_loss: 49.6782 - Channels_accuracy: 0.7322 - Notes_accuracy: 0.1217 - Velocities_rounded_accuracy: 0.0112 - Time-Ticks_rounded_accuracy: 0.0635
# Epoch 3/13
# 358/358 [==============================] - 147s 409ms/step - loss: 29.2810 - Channels_loss: 0.5152 - Notes_loss: 3.0757 - Velocities_loss: 682.2345 - Time-Ticks_loss: 21.6504 - Channels_accuracy: 0.7459 - Notes_accuracy: 0.1618 - Velocities_rounded_accuracy: 0.0117 - Time-Ticks_rounded_accuracy: 0.1554
# Epoch 4/13
# 358/358 [==============================] - 115s 321ms/step - loss: 28.5739 - Channels_loss: 0.4920 - Notes_loss: 2.9913 - Velocities_loss: 668.5782 - Time-Ticks_loss: 12.0582 - Channels_accuracy: 0.7566 - Notes_accuracy: 0.1861 - Velocities_rounded_accuracy: 0.0127 - Time-Ticks_rounded_accuracy: 0.2175
# Epoch 5/13
# 358/358 [==============================] - 122s 341ms/step - loss: 28.0279 - Channels_loss: 0.4795 - Notes_loss: 2.9354 - Velocities_loss: 655.5671 - Time-Ticks_loss: 7.9316 - Channels_accuracy: 0.7635 - Notes_accuracy: 0.2018 - Velocities_rounded_accuracy: 0.0249 - Time-Ticks_rounded_accuracy: 0.2667
# Epoch 6/13
# 358/358 [==============================] - 123s 343ms/step - loss: 27.6038 - Channels_loss: 0.4723 - Notes_loss: 2.8941 - Velocities_loss: 644.8616 - Time-Ticks_loss: 5.7965 - Channels_accuracy: 0.7668 - Notes_accuracy: 0.2140 - Velocities_rounded_accuracy: 0.0411 - Time-Ticks_rounded_accuracy: 0.3051
# Epoch 7/13
# 358/358 [==============================] - 122s 342ms/step - loss: 27.1760 - Channels_loss: 0.4652 - Notes_loss: 2.8599 - Velocities_loss: 632.1994 - Time-Ticks_loss: 4.6014 - Channels_accuracy: 0.7710 - Notes_accuracy: 0.2246 - Velocities_rounded_accuracy: 0.0648 - Time-Ticks_rounded_accuracy: 0.3431
# Epoch 8/13
# 358/358 [==============================] - 152s 425ms/step - loss: 26.7735 - Channels_loss: 0.4603 - Notes_loss: 2.8298 - Velocities_loss: 619.7068 - Time-Ticks_loss: 3.5374 - Channels_accuracy: 0.7733 - Notes_accuracy: 0.2337 - Velocities_rounded_accuracy: 0.0895 - Time-Ticks_rounded_accuracy: 0.4192
# Epoch 9/13
# 358/358 [==============================] - 127s 356ms/step - loss: 26.4143 - Channels_loss: 0.4562 - Notes_loss: 2.8051 - Velocities_loss: 608.0232 - Time-Ticks_loss: 2.9823 - Channels_accuracy: 0.7758 - Notes_accuracy: 0.2414 - Velocities_rounded_accuracy: 0.1147 - Time-Ticks_rounded_accuracy: 0.4622
# Epoch 10/13
# 358/358 [==============================] - 128s 358ms/step - loss: 26.0844 - Channels_loss: 0.4529 - Notes_loss: 2.7845 - Velocities_loss: 596.7647 - Time-Ticks_loss: 2.4895 - Channels_accuracy: 0.7779 - Notes_accuracy: 0.2476 - Velocities_rounded_accuracy: 0.1367 - Time-Ticks_rounded_accuracy: 0.5034
# Epoch 11/13
# 358/358 [==============================] - 122s 340ms/step - loss: 25.7537 - Channels_loss: 0.4492 - Notes_loss: 2.7642 - Velocities_loss: 585.3978 - Time-Ticks_loss: 2.1471 - Channels_accuracy: 0.7812 - Notes_accuracy: 0.2534 - Velocities_rounded_accuracy: 0.1445 - Time-Ticks_rounded_accuracy: 0.5420
# Epoch 12/13
# 358/358 [==============================] - 120s 334ms/step - loss: 25.4191 - Channels_loss: 0.4453 - Notes_loss: 2.7462 - Velocities_loss: 573.2657 - Time-Ticks_loss: 1.7698 - Channels_accuracy: 0.7841 - Notes_accuracy: 0.2585 - Velocities_rounded_accuracy: 0.1630 - Time-Ticks_rounded_accuracy: 0.5956
# Epoch 13/13
# 358/358 [==============================] - 127s 356ms/step - loss: 25.1384 - Channels_loss: 0.4428 - Notes_loss: 2.7322 - Velocities_loss: 562.8083 - Time-Ticks_loss: 1.5283 - Channels_accuracy: 0.7864 - Notes_accuracy: 0.2629 - Velocities_rounded_accuracy: 0.1697 - Time-Ticks_rounded_accuracy: 0.6270

# %%
lossLSTM.append(historyLSTM.history['loss'])
channels_accuracyLSTM.append(historyLSTM.history['Channels_accuracy'])
notes_accuracyLSTM.append(historyLSTM.history['Notes_accuracy'])
velocities_accuracyLSTM.append(historyLSTM.history['Velocities_rounded_accuracy'])
ticks_accuracyLSTM.append(historyLSTM.history['Time-Ticks_rounded_accuracy'])

# %%
##get the notes loss
notes_lossLSTM = historyLSTM.history['Notes_loss']
channel_lossLSTM = historyLSTM.history['Channels_loss']
plt.figure()
plt.plot(notes_lossLSTM)
plt.plot(channel_lossLSTM)
plt.title("Notes and channel losses")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Notes', 'Channels'])

# %%
##Plotting
plt.figure()
plt.plot(lossLSTM[0])
plt.title("Training our Multi-Input Multi-Output LSTM")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
plt.figure
plt.plot(channels_accuracyLSTM[0])
plt.plot(notes_accuracyLSTM[0])
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Channels', 'Notes'])

# %%
##LSTM with other parameters
dim = 300

losses= {
    'Channels': 'categorical_crossentropy',
    'Notes': 'categorical_crossentropy',
    'Velocities': 'mean_squared_error',
    'Time-Ticks': 'mean_squared_error'
}

loss_weights = {
    'Channels': 0.5,
    'Notes': 10.0,
    'Velocities': 0.02,
    'Time-Ticks': 2e-7
}

metrics = {
    'Channels': 'accuracy',
    'Notes': 'accuracy',
    'Velocities': rounded_accuracy,
    'Time-Ticks': rounded_accuracy
}

# %%
n_epochs = 13
LSTMmodel.compile(optimizer='adam', loss=losses, loss_weights=loss_weights, metrics=metrics)
historyLSTM = LSTMmodel.fit([X_channels, X_notes, X_velocities, X_ticks], [y_channels, y_notes, y_velocities, y_ticks], epochs=n_epochs, batch_size=n_batch)
# Out:
# Epoch 1/13
# 358/358 [==============================] - 146s 377ms/step - loss: 38.3076 - Channels_loss: 0.4382 - Notes_loss: 2.7054 - Velocities_loss: 551.7170 - Time-Ticks_loss: 0.8015 - Channels_accuracy: 0.7902 - Notes_accuracy: 0.2692 - Velocities_rounded_accuracy: 0.1602 - Time-Ticks_rounded_accuracy: 0.7988
# Epoch 2/13
# 358/358 [==============================] - 129s 361ms/step - loss: 37.9091 - Channels_loss: 0.4357 - Notes_loss: 2.6802 - Velocities_loss: 544.4566 - Time-Ticks_loss: 0.3194 - Channels_accuracy: 0.7926 - Notes_accuracy: 0.2758 - Velocities_rounded_accuracy: 0.1673 - Time-Ticks_rounded_accuracy: 0.9140
# Epoch 3/13
# 358/358 [==============================] - 125s 348ms/step - loss: 37.5471 - Channels_loss: 0.4330 - Notes_loss: 2.6605 - Velocities_loss: 536.2587 - Time-Ticks_loss: 0.2018 - Channels_accuracy: 0.7949 - Notes_accuracy: 0.2808 - Velocities_rounded_accuracy: 0.1735 - Time-Ticks_rounded_accuracy: 0.9420
# Epoch 4/13
# 358/358 [==============================] - 129s 361ms/step - loss: 37.2423 - Channels_loss: 0.4308 - Notes_loss: 2.6445 - Velocities_loss: 529.0874 - Time-Ticks_loss: 0.1576 - Channels_accuracy: 0.7971 - Notes_accuracy: 0.2855 - Velocities_rounded_accuracy: 0.1787 - Time-Ticks_rounded_accuracy: 0.9533
# Epoch 5/13
# 358/358 [==============================] - 127s 354ms/step - loss: 36.9101 - Channels_loss: 0.4288 - Notes_loss: 2.6277 - Velocities_loss: 520.9593 - Time-Ticks_loss: 0.1315 - Channels_accuracy: 0.7987 - Notes_accuracy: 0.2899 - Velocities_rounded_accuracy: 0.1801 - Time-Ticks_rounded_accuracy: 0.9614
# Epoch 6/13
# 358/358 [==============================] - 126s 351ms/step - loss: 36.6273 - Channels_loss: 0.4274 - Notes_loss: 2.6143 - Velocities_loss: 513.5085 - Time-Ticks_loss: 0.1175 - Channels_accuracy: 0.8000 - Notes_accuracy: 0.2934 - Velocities_rounded_accuracy: 0.1846 - Time-Ticks_rounded_accuracy: 0.9659
# Epoch 7/13
# 358/358 [==============================] - 127s 356ms/step - loss: 36.3645 - Channels_loss: 0.4262 - Notes_loss: 2.6022 - Velocities_loss: 506.4908 - Time-Ticks_loss: 0.1060 - Channels_accuracy: 0.8011 - Notes_accuracy: 0.2963 - Velocities_rounded_accuracy: 0.1866 - Time-Ticks_rounded_accuracy: 0.9698
# Epoch 8/13
# 358/358 [==============================] - 125s 349ms/step - loss: 36.1058 - Channels_loss: 0.4254 - Notes_loss: 2.5907 - Velocities_loss: 499.2875 - Time-Ticks_loss: 0.0992 - Channels_accuracy: 0.8023 - Notes_accuracy: 0.2995 - Velocities_rounded_accuracy: 0.1926 - Time-Ticks_rounded_accuracy: 0.9730
# Epoch 9/13
# 358/358 [==============================] - 126s 353ms/step - loss: 35.8600 - Channels_loss: 0.4245 - Notes_loss: 2.5805 - Velocities_loss: 492.1347 - Time-Ticks_loss: 0.0929 - Channels_accuracy: 0.8025 - Notes_accuracy: 0.3022 - Velocities_rounded_accuracy: 0.1925 - Time-Ticks_rounded_accuracy: 0.9750
# Epoch 10/13
# 358/358 [==============================] - 126s 351ms/step - loss: 35.6192 - Channels_loss: 0.4237 - Notes_loss: 2.5695 - Velocities_loss: 485.6070 - Time-Ticks_loss: 0.0880 - Channels_accuracy: 0.8033 - Notes_accuracy: 0.3052 - Velocities_rounded_accuracy: 0.2008 - Time-Ticks_rounded_accuracy: 0.9783
# Epoch 11/13
# 358/358 [==============================] - 125s 350ms/step - loss: 35.4156 - Channels_loss: 0.4234 - Notes_loss: 2.5620 - Velocities_loss: 479.1712 - Time-Ticks_loss: 0.0851 - Channels_accuracy: 0.8038 - Notes_accuracy: 0.3070 - Velocities_rounded_accuracy: 0.1982 - Time-Ticks_rounded_accuracy: 0.9796
# Epoch 12/13
# 358/358 [==============================] - 163s 456ms/step - loss: 35.1815 - Channels_loss: 0.4229 - Notes_loss: 2.5528 - Velocities_loss: 472.1194 - Time-Ticks_loss: 0.0822 - Channels_accuracy: 0.8039 - Notes_accuracy: 0.3098 - Velocities_rounded_accuracy: 0.2053 - Time-Ticks_rounded_accuracy: 0.9824
# Epoch 13/13
# 358/358 [==============================] - 123s 343ms/step - loss: 35.0065 - Channels_loss: 0.4225 - Notes_loss: 2.5462 - Velocities_loss: 466.6444 - Time-Ticks_loss: 0.0794 - Channels_accuracy: 0.8046 - Notes_accuracy: 0.3114 - Velocities_rounded_accuracy: 0.2069 - Time-Ticks_rounded_accuracy: 0.9844

# %%
##get the accuracy :
lossLSTM.append(historyLSTM.history['loss'])
channels_accuracyLSTM.append(historyLSTM.history['Channels_accuracy'])
notes_accuracyLSTM.append(historyLSTM.history['Notes_accuracy'])
velocities_accuracyLSTM.append(historyLSTM.history['Velocities_rounded_accuracy'])
ticks_accuracyLSTM.append(historyLSTM.history['Time-Ticks_rounded_accuracy'])

##Plot the accuracy
plt.figure()
plt.plot(channels_accuracyLSTM[0])
plt.plot(notes_accuracyLSTM[0])
plt.plot(velocities_accuracyLSTM[0])
plt.plot(ticks_accuracyLSTM[0])
plt.title("Accuracy of the four variables for factor 10 on notes loss")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Channels', 'Notes', 'Velocities', 'Time-Ticks']) 
plt.show()

# %%
##LSTM with other parameters
dim = 300

losses= {
    'Channels': 'categorical_crossentropy',
    'Notes': 'categorical_crossentropy',
    'Velocities': 'mean_squared_error',
    'Time-Ticks': 'mean_squared_error'
}

loss_weights = {
    'Channels': 0.2,
    'Notes': 15.0,
    'Velocities': 0.04,
    'Time-Ticks': 2e-7
}

metrics = {
    'Channels': 'accuracy',
    'Notes': 'accuracy',
    'Velocities': rounded_accuracy,
    'Time-Ticks': rounded_accuracy
}

# %%
n_epochs = 13
LSTMmodel.compile(optimizer='adam', loss=losses, loss_weights=loss_weights, metrics=metrics)
historyLSTM = LSTMmodel.fit([X_channels, X_notes, X_velocities, X_ticks], [y_channels, y_notes, y_velocities, y_ticks], epochs=n_epochs, batch_size=n_batch)
# Out:
# Epoch 1/13
# 358/358 [==============================] - 155s 414ms/step - loss: 56.6746 - Channels_loss: 0.4236 - Notes_loss: 2.5430 - Velocities_loss: 461.1297 - Time-Ticks_loss: 0.0802 - Channels_accuracy: 0.8038 - Notes_accuracy: 0.3121 - Velocities_rounded_accuracy: 0.2141 - Time-Ticks_rounded_accuracy: 0.9837
# Epoch 2/13
# 358/358 [==============================] - 134s 375ms/step - loss: 56.3097 - Channels_loss: 0.4244 - Notes_loss: 2.5389 - Velocities_loss: 453.5190 - Time-Ticks_loss: 0.0788 - Channels_accuracy: 0.8038 - Notes_accuracy: 0.3133 - Velocities_rounded_accuracy: 0.2161 - Time-Ticks_rounded_accuracy: 0.9847
# Epoch 3/13
# 358/358 [==============================] - 136s 381ms/step - loss: 56.0254 - Channels_loss: 0.4254 - Notes_loss: 2.5354 - Velocities_loss: 447.7387 - Time-Ticks_loss: 0.0780 - Channels_accuracy: 0.8029 - Notes_accuracy: 0.3143 - Velocities_rounded_accuracy: 0.2197 - Time-Ticks_rounded_accuracy: 0.9856
# Epoch 4/13
# 358/358 [==============================] - 133s 372ms/step - loss: 55.7371 - Channels_loss: 0.4254 - Notes_loss: 2.5321 - Velocities_loss: 441.7604 - Time-Ticks_loss: 0.0767 - Channels_accuracy: 0.8036 - Notes_accuracy: 0.3151 - Velocities_rounded_accuracy: 0.2208 - Time-Ticks_rounded_accuracy: 0.9866
# Epoch 5/13
# 358/358 [==============================] - 135s 376ms/step - loss: 55.4820 - Channels_loss: 0.4264 - Notes_loss: 2.5292 - Velocities_loss: 436.4561 - Time-Ticks_loss: 0.0753 - Channels_accuracy: 0.8028 - Notes_accuracy: 0.3161 - Velocities_rounded_accuracy: 0.2237 - Time-Ticks_rounded_accuracy: 0.9873
# Epoch 6/13
# 358/358 [==============================] - 133s 372ms/step - loss: 55.2427 - Channels_loss: 0.4265 - Notes_loss: 2.5261 - Velocities_loss: 431.6552 - Time-Ticks_loss: 0.0746 - Channels_accuracy: 0.8031 - Notes_accuracy: 0.3167 - Velocities_rounded_accuracy: 0.2251 - Time-Ticks_rounded_accuracy: 0.9882
# Epoch 7/13
# 358/358 [==============================] - 133s 371ms/step - loss: 55.0049 - Channels_loss: 0.4267 - Notes_loss: 2.5231 - Velocities_loss: 426.8207 - Time-Ticks_loss: 0.0735 - Channels_accuracy: 0.8033 - Notes_accuracy: 0.3173 - Velocities_rounded_accuracy: 0.2270 - Time-Ticks_rounded_accuracy: 0.9893
# Epoch 8/13
# 358/358 [==============================] - 133s 372ms/step - loss: 54.7306 - Channels_loss: 0.4272 - Notes_loss: 2.5192 - Velocities_loss: 421.4380 - Time-Ticks_loss: 0.0724 - Channels_accuracy: 0.8026 - Notes_accuracy: 0.3185 - Velocities_rounded_accuracy: 0.2299 - Time-Ticks_rounded_accuracy: 0.9899
# Epoch 9/13
# 358/358 [==============================] - 132s 368ms/step - loss: 54.5401 - Channels_loss: 0.4272 - Notes_loss: 2.5173 - Velocities_loss: 417.3756 - Time-Ticks_loss: 0.0717 - Channels_accuracy: 0.8030 - Notes_accuracy: 0.3191 - Velocities_rounded_accuracy: 0.2331 - Time-Ticks_rounded_accuracy: 0.9905
# Epoch 10/13
# 358/358 [==============================] - 134s 373ms/step - loss: 54.2905 - Channels_loss: 0.4277 - Notes_loss: 2.5135 - Velocities_loss: 412.5498 - Time-Ticks_loss: 0.0709 - Channels_accuracy: 0.8030 - Notes_accuracy: 0.3200 - Velocities_rounded_accuracy: 0.2340 - Time-Ticks_rounded_accuracy: 0.9910
# Epoch 11/13
# 358/358 [==============================] - 133s 370ms/step - loss: 54.1078 - Channels_loss: 0.4278 - Notes_loss: 2.5113 - Velocities_loss: 408.8003 - Time-Ticks_loss: 0.0701 - Channels_accuracy: 0.8029 - Notes_accuracy: 0.3204 - Velocities_rounded_accuracy: 0.2353 - Time-Ticks_rounded_accuracy: 0.9914
# Epoch 12/13
# 358/358 [==============================] - 136s 380ms/step - loss: 53.8614 - Channels_loss: 0.4280 - Notes_loss: 2.5080 - Velocities_loss: 403.9029 - Time-Ticks_loss: 0.0693 - Channels_accuracy: 0.8029 - Notes_accuracy: 0.3211 - Velocities_rounded_accuracy: 0.2373 - Time-Ticks_rounded_accuracy: 0.9919
# Epoch 13/13
# 358/358 [==============================] - 136s 381ms/step - loss: 53.7191 - Channels_loss: 0.4284 - Notes_loss: 2.5066 - Velocities_loss: 400.8534 - Time-Ticks_loss: 0.0688 - Channels_accuracy: 0.8027 - Notes_accuracy: 0.3218 - Velocities_rounded_accuracy: 0.2386 - Time-Ticks_rounded_accuracy: 0.9923

# %%
##get the accuracy :
lossLSTM=[]
channels_accuracyLSTM=[]
notes_accuracyLSTM=[]
velocities_accuracyLSTM=[]
lossLSTM.append(historyLSTM.history['loss'])
channels_accuracyLSTM.append(historyLSTM.history['Channels_accuracy'])
notes_accuracyLSTM.append(historyLSTM.history['Notes_accuracy'])
velocities_accuracyLSTM.append(historyLSTM.history['Velocities_rounded_accuracy'])
ticks_accuracyLSTM.append(historyLSTM.history['Time-Ticks_rounded_accuracy'])

##Plot the accuracy
plt.figure()
plt.plot(channels_accuracyLSTM[0])
plt.plot(notes_accuracyLSTM[0])
plt.plot(velocities_accuracyLSTM[0])
plt.plot(ticks_accuracyLSTM[0])
plt.title("Accuracy of the four variables for factor 10 on notes loss")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Channels', 'Notes', 'Velocities', 'Time-Ticks']) 
plt.show()

# %%
##Transformer 
from keras.layers import MultiHeadAttention, LayerNormalization, Add
from keras.models import Model
from keras import layers
from keras import Input
from keras import optimizers

def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    x = LayerNormalization()(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = Add()([inputs, x])
    y = x
    x = LayerNormalization()(x)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    x = Add()([y, x])
    return x

def build_transformer(n_Channels,n_Notes,head_size,num_heads,ff_dim,num_transformer_blocks,mlp_units,dropout=0,mlp_dropout=0):
    input_channels = Input(shape=(None, n_Channels))
    input_notes = Input(shape=(None, n_Notes))
    input_velocities = Input(shape=(None, 1))
    input_ticks = Input(shape=(None, 1))
    x_channels = layers.Embedding(n_Channels, 128)(input_channels)
    x_notes = layers.Embedding(n_Notes, 128)(input_notes)
    x_velocities = layers.Embedding(1, 128)(input_velocities)
    x_ticks = layers.Embedding(1, 128)(input_ticks)
    ##concatenate the inputs but they are not the same size
    x = layers.concatenate([x_channels, x_notes, x_velocities, x_ticks], axis=2)
    x = layers.Conv1D(128, 1, activation="relu")(x)
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)
    x_channels = layers.Conv1D(n_Channels, 1)(x)
    x_channels = layers.Softmax(name="Channels")(x_channels)
    x_notes = layers.Conv1D(n_Notes, 1)(x)
    x_notes = layers.Softmax(name="Notes")(x_notes)
    x_velocities = layers.Conv1D(1, 1)(x)
    x_velocities = layers.Lambda(lambda x: (tf.sigmoid(x) * (velocity_range[1] - velocity_range[0]) + velocity_range[0]), name="Velocities")(x_velocities)
    x_ticks = layers.Conv1D(1, 1)(x)
    x_ticks = layers.Lambda(lambda x: (tf.sigmoid(x) * (tick_range[1] - tick_range[0]) + tick_range[0]), name="Time-Ticks")(x_ticks)
    return Model(inputs=[input_channels, input_notes, input_velocities, input_ticks], outputs=[x_channels, x_notes, x_velocities, x_ticks])


head_size = 256
num_heads = 4
ff_dim = 4
num_transformer_blocks = 3  
mlp_units = [128]
mlp_dropout = 0.4
dropout = 0.25

transformer = build_transformer(n_Channels,n_Notes, head_size, num_heads, ff_dim, num_transformer_blocks, mlp_units, dropout=dropout, mlp_dropout=mlp_dropout)
transformer.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_18 (InputLayer)          [(None, None, 12)]   0           []
#
#  input_19 (InputLayer)          [(None, None, 105)]  0           []
#
#  input_20 (InputLayer)          [(None, None, 1)]    0           []
#
#  input_21 (InputLayer)          [(None, None, 1)]    0           []
#
#  embedding_12 (Embedding)       (None, None, 12, 12  1536        ['input_18[0][0]']
#                                 8)
#
#  embedding_13 (Embedding)       (None, None, 105, 1  13440       ['input_19[0][0]']
#                                 28)
#
#  embedding_14 (Embedding)       (None, None, 1, 128  128         ['input_20[0][0]']
#                                 )
#
#  embedding_15 (Embedding)       (None, None, 1, 128  128         ['input_21[0][0]']
#                                 )
#
#  concatenate_4 (Concatenate)    (None, None, 119, 1  0           ['embedding_12[0][0]',
#                                 28)                               'embedding_13[0][0]',
#                                                                   'embedding_14[0][0]',
#                                                                   'embedding_15[0][0]']
#
#  conv1d_6 (Conv1D)              (None, None, 119, 1  16512       ['concatenate_4[0][0]']
#                                 28)
#
#  layer_normalization_7 (LayerNo  (None, None, 119, 1  256        ['conv1d_6[0][0]']
#  rmalization)                   28)
#
#  multi_head_attention_3 (MultiH  (None, None, 119, 1  527488     ['layer_normalization_7[0][0]',
#  eadAttention)                  28)                               'layer_normalization_7[0][0]']
#
#  add_8 (Add)                    (None, None, 119, 1  0           ['conv1d_6[0][0]',
#                                 28)                               'multi_head_attention_3[0][0]']
#
#  layer_normalization_8 (LayerNo  (None, None, 119, 1  256        ['add_8[0][0]']
#  rmalization)                   28)
#
#  conv1d_7 (Conv1D)              (None, None, 119, 4  516         ['layer_normalization_8[0][0]']
#                                 )
#
#  conv1d_8 (Conv1D)              (None, None, 119, 1  640         ['conv1d_7[0][0]']
#                                 28)
#
#  add_9 (Add)                    (None, None, 119, 1  0           ['add_8[0][0]',
#                                 28)                               'conv1d_8[0][0]']
#
#  layer_normalization_9 (LayerNo  (None, None, 119, 1  256        ['add_9[0][0]']
#  rmalization)                   28)
#
#  multi_head_attention_4 (MultiH  (None, None, 119, 1  527488     ['layer_normalization_9[0][0]',
#  eadAttention)                  28)                               'layer_normalization_9[0][0]']
#
#  add_10 (Add)                   (None, None, 119, 1  0           ['add_9[0][0]',
#                                 28)                               'multi_head_attention_4[0][0]']
#
#  layer_normalization_10 (LayerN  (None, None, 119, 1  256        ['add_10[0][0]']
#  ormalization)                  28)
#
#  conv1d_9 (Conv1D)              (None, None, 119, 4  516         ['layer_normalization_10[0][0]']
#                                 )
#
#  conv1d_10 (Conv1D)             (None, None, 119, 1  640         ['conv1d_9[0][0]']
#                                 28)
#
#  add_11 (Add)                   (None, None, 119, 1  0           ['add_10[0][0]',
#                                 28)                               'conv1d_10[0][0]']
#
#  layer_normalization_11 (LayerN  (None, None, 119, 1  256        ['add_11[0][0]']
#  ormalization)                  28)
#
#  multi_head_attention_5 (MultiH  (None, None, 119, 1  527488     ['layer_normalization_11[0][0]',
#  eadAttention)                  28)                               'layer_normalization_11[0][0]']
#
#  add_12 (Add)                   (None, None, 119, 1  0           ['add_11[0][0]',
#                                 28)                               'multi_head_attention_5[0][0]']
#
#  layer_normalization_12 (LayerN  (None, None, 119, 1  256        ['add_12[0][0]']
#  ormalization)                  28)
#
#  conv1d_11 (Conv1D)             (None, None, 119, 4  516         ['layer_normalization_12[0][0]']
#                                 )
#
#  conv1d_12 (Conv1D)             (None, None, 119, 1  640         ['conv1d_11[0][0]']
#                                 28)
#
#  add_13 (Add)                   (None, None, 119, 1  0           ['add_12[0][0]',
#                                 28)                               'conv1d_12[0][0]']
#
#  conv1d_13 (Conv1D)             (None, None, 119, 1  1548        ['add_13[0][0]']
#                                 2)
#
#  conv1d_14 (Conv1D)             (None, None, 119, 1  13545       ['add_13[0][0]']
#                                 05)
#
#  conv1d_15 (Conv1D)             (None, None, 119, 1  129         ['add_13[0][0]']
#                                 )
#
#  conv1d_16 (Conv1D)             (None, None, 119, 1  129         ['add_13[0][0]']
#                                 )
#
#  Channels (Softmax)             (None, None, 119, 1  0           ['conv1d_13[0][0]']
#                                 2)
#
#  Notes (Softmax)                (None, None, 119, 1  0           ['conv1d_14[0][0]']
#                                 05)
#
#  Velocities (Lambda)            (None, None, 119, 1  0           ['conv1d_15[0][0]']
#                                 )
#
#  Time-Ticks (Lambda)            (None, None, 119, 1  0           ['conv1d_16[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 1,634,563
# Trainable params: 1,634,563
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
##Train it
n_epochs = 10
transformer.compile(optimizer='adam', loss=losses, loss_weights=loss_weights, metrics=metrics)
historyTransformer = transformer.fit([X_channels, X_notes, X_velocities, X_ticks], [y_channels, y_notes, y_velocities, y_ticks], epochs=n_epochs, batch_size=n_batch)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 4
#       2 n_epochs = 10
#       3 transformer.compile(optimizer='adam', loss=losses, loss_weights=loss_weights, metrics=metrics)
# ----> 4 historyTransformer = transformer.fit([X_channels, X_notes, X_velocities, X_ticks], [y_channels, y_notes, y_velocities, y_ticks], epochs=n_epochs, batch_size=n_batch)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_file7zi8300r.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "C:\Users\mxrin\AppData\Roaming\Python\Python311\site-packages\keras\engine\training.py", line 1284, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\mxrin\AppData\Roaming\Python\Python311\site-packages\keras\engine\training.py", line 1268, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\mxrin\AppData\Roaming\Python\Python311\site-packages\keras\engine\training.py", line 1249, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\mxrin\AppData\Roaming\Python\Python311\site-packages\keras\engine\training.py", line 1051, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "C:\Users\mxrin\AppData\Roaming\Python\Python311\site-packages\keras\engine\training.py", line 1109, in compute_loss
#         return self.compiled_loss(
#     File "C:\Users\mxrin\AppData\Roaming\Python\Python311\site-packages\keras\engine\compile_utils.py", line 265, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "C:\Users\mxrin\AppData\Roaming\Python\Python311\site-packages\keras\losses.py", line 142, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "C:\Users\mxrin\AppData\Roaming\Python\Python311\site-packages\keras\losses.py", line 268, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "C:\Users\mxrin\AppData\Roaming\Python\Python311\site-packages\keras\losses.py", line 1984, in categorical_crossentropy
#         return backend.categorical_crossentropy(
#     File "C:\Users\mxrin\AppData\Roaming\Python\Python311\site-packages\keras\backend.py", line 5559, in categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#
#     ValueError: Shapes (200, 30, 12) and (200, 30, 119, 12) are incompatible

# %%
##Define a function that print the next sequence of notes :
def print_notes(generated_channels, generated_notes, generated_velocities, generated_ticks):
    for i in range(100):
        channel = np.argmax(generated_channels[0,i])
        note = np.argmax(generated_notes[0,i])
        velocity = generated_velocities[0,i]
        tick = generated_ticks[0,i]
        print("Channel : ",ind_to_channel[channel]," Note : ",ind_to_note[note]," Velocity : ",velocity," Tick : ",tick)

# %%
def next_sequence(input_channel_data,input_notes_data,input_velocities_data,input_ticks_data, model):
  

    predictions = model.predict([input_channel_data, input_notes_data, input_velocities_data, input_ticks_data])

    channels_prediction, notes_prediction, velocities_prediction, ticks_prediction = predictions



    return channels_prediction, notes_prediction, velocities_prediction, ticks_prediction

# %%
def UpdateVect(original_vector,new_vector):
    new_vector_expanded = new_vector.reshape(1, 1, len(new_vector))


    extended_vector = np.append(original_vector, new_vector_expanded, axis=1)

    modified_vector = np.delete(extended_vector, 0, axis=1)
    return modified_vector

# %%
input_channels_data = X_channels[0:1,:,:]
input_notes_data = X_notes[0:1,:,:]
input_velocities_data = X_velocities[0:1,:,:]
input_ticks_data = X_ticks[0:1,:,:]

channel=[input_channels_data]
notes=[input_notes_data]
velocities=[input_velocities_data]
ticks=[input_ticks_data]

for k in range(4):
    print(k)
    channels_prediction, notes_prediction, velocities_prediction, ticks_prediction=next_sequence(channel[-1],notes[-1],velocities[-1],ticks[-1], model)
    # Select the most probable note using argmax
    next_note = ind_to_note[np.argmax(notes_prediction[0, -1, :])]
    next_channel = ind_to_channel[np.argmax(channels_prediction[0, -1, :])]
    next_velocity = velocities_prediction[0, -1, 0]
    next_tick = ticks_prediction[0, -1, 0]
    print(next_note)
        # Append the selected note to the generated sequence
    #generated_notes.append(next_note)

        # Prepare the input for the next prediction
    channel.append(next_channel)
    notes.append(next_note)
    velocities.append(next_velocity)
    ticks.append(next_tick)
    OneHotChannels = pp.one_hot_encode(channel_to_ind,next_channel)
    OneHotNotes = pp.one_hot_encode(note_to_ind,next_note)
    AllVelocities = next_velocity.reshape((-1,1))
    AllTicks = AllTicks.reshape((-1,1))
    X_channels=UpdateVect(X_channels,OneHotChannels)
    X_notes=UpdateVect(X_notes,OneHotNotes)
    X_velocities=UpdateVect(X_velocities,AllVelocities)
    X_ticks=UpdateVect(X_ticks,AllTicks)
# Out:
# 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 74
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 32
#      30 AllVelocities = next_velocity.reshape((-1,1))
#      31 AllTicks = AllTicks.reshape((-1,1))
# ---> 32 X_channels=UpdateVect(X_channels,OneHotChannels)
#      33 X_notes=UpdateVect(X_notes,OneHotNotes)
#      34 X_velocities=UpdateVect(X_velocities,AllVelocities)
#
# Cell In[35], line 5, in UpdateVect(original_vector, new_vector)
#       1 def UpdateVect(original_vector,new_vector):
#       2     new_vector_expanded = new_vector.reshape(1, 1, len(new_vector))
# ----> 5     extended_vector = np.append(original_vector, new_vector_expanded, axis=1)
#       7     modified_vector = np.delete(extended_vector, 0, axis=1)
#       8     return modified_vector
#
# File c:\Users\anhly\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\lib\function_base.py:5618, in append(arr, values, axis)
#    5616     values = ravel(values)
#    5617     axis = arr.ndim-1
# -> 5618 return concatenate((arr, values), axis=axis)
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 71600 and the array at index 1 has size 1

# %%
#X_channels[0:1,:,:].shape
OneHotChannels.shape
# Out:
# (12,)

# %%
ind_to_note(63)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 ind_to_note(63)
#
# TypeError: 'dict' object is not callable

# %%
#decode the data

# %%
from midiutil import MIDIFile

# %%
def CreateMIDIFile(channel,note,volume,ticks):
    MyMIDI = MIDIFile(1)  # One track, defaults to format 1 
    track=0
    tempo=60
    time=0
    MyMIDI.addTempo(track, time, tempo)

    for i, pitch in enumerate(AllNotes):
        MyMIDI.addNote(0, channel[i], pitch, time + i, ticks[i], volume[i])

    with open("major-scale.mid", "wb") as output_file:
        MyMIDI.writeFile(output_file)
