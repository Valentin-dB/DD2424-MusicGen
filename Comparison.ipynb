# %%
import mido
import numpy as np
import matplotlib.pyplot as plt
import PreProcessor as pp
import gc
from keras.models import Model
from tensorflow.keras.layers import Input, SimpleRNN, LSTM, GRU, Dense, Lambda, Softmax, Activation, concatenate
from keras import optimizers
import tensorflow as tf

# %%
dataset = pp.load_dataset("adl-piano-midi")
ClassicSongs = pp.files_to_songs(dataset["Classical"])

channel_to_ind, ind_to_channel, note_to_ind, ind_to_note, velocity_to_ind, ind_to_velocity = pp.dicts_from_songs(ClassicSongs)
time_range = pp.ranges_from_songs(ClassicSongs)

n_Channels = len(channel_to_ind)
n_Notes = len(note_to_ind)
n_Velocities = len(velocity_to_ind)

print("\nNumber of channels   :",n_Channels,"\nNumber of notes      :",n_Notes,"\nNumber of velocities :",n_Velocities,"\nTime range           :",time_range[0],time_range[1])
# Out:
# Couldn't load : adl-piano-midi\Classical\Classical\Alexander Borodin\Nocturne.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Antonio Salieri\Invention.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Bela Bartok\Andante.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Bela Bartok\Romanian Folk Dance.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Claude Debussy\Clair De Lune.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Franz Schubert\Impromptu in C-Moll.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Franz Schubert\Impromptu in Ges-dur.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Franz Schubert\Trois Marches militaires 3.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Frederic Chopin\Prelude Op 28 No7.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Giacomo Puccini\O Mio Babibino Caro.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Jean-Baptiste Lully\Minuet.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Johann Sebastian Bach\Aria, BWV 515.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Johann Sebastian Bach\Aus meines Herzens Grunde (Chorale 1).mid
# Couldn't load : adl-piano-midi\Classical\Classical\Johann Sebastian Bach\English Suite 3 Gavotte.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Johann Sebastian Bach\Gib dich zufrieden und sei stille.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Johann Sebastian Bach\Invention 1, BWV 772.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Johann Sebastian Bach\Invention 5.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Johann Sebastian Bach\Invention 6.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Johann Sebastian Bach\Invention No 8.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Johann Sebastian Bach\Sleepers, Wake.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Ludwig van Beethoven\Moonlight Sonata 1st movement.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Ludwig van Beethoven\Moonlight Sonata 3rd Movement.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Ludwig van Beethoven\Sonata for Piano with Horn, Op 17.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Pyotr Ilyich Tchaikovsky\July - Song of the Reaper.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Pyotr Ilyich Tchaikovsky\March - Song of the Lark.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Pyotr Ilyich Tchaikovsky\Nutcracker Minature Overture.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Richard Wagner\Bridal March.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Richard Wagner\Ride of the Valkyries.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Robert Schumann\Curious Story.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Wolfgang Amadeus Mozart\Clarinet Concerto Theme.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Wolfgang Amadeus Mozart\Minuet from Don Juan.mid
# Couldn't load : adl-piano-midi\Classical\Classical\Wolfgang Amadeus Mozart\Theme from C K467.mid
# Couldn't load : adl-piano-midi\Classical\German Baroque\Johann Krieger\Minuet.mid
# Couldn't load : adl-piano-midi\Classical\Late Romantic Era\Charles-Valentin Alkan\Prélude.mid
# Couldn't load : adl-piano-midi\Classical\Late Romantic Era\Charles-Valentin Alkan\Saltarelle.mid
# Couldn't load : adl-piano-midi\Classical\Neo-Classical\Ludovico Einaudi\Divenire.mid
# Couldn't load : adl-piano-midi\Classical\Neo-Classical\Yiruma\Rivers Flow in You.mid
# Couldn't load : adl-piano-midi\Classical\Operatic Pop\Yanni\Hijo de la Luna.mid
# Couldn't load : adl-piano-midi\Classical\Post-Romantic Era\Vladimir Rebikov\The Bear.mid
#
# Number of channels   : 12
# Number of notes      : 105
# Number of velocities : 128
# Time range           : 0.0 190.285

# %%
def rounded_accuracy(y_true, y_pred):
    y_pred_rounded = tf.round(y_pred)
    correct_predictions = tf.equal(tf.cast(y_pred_rounded, tf.int32), tf.cast(y_true, tf.int32))
    accuracy = tf.reduce_mean(tf.cast(correct_predictions, tf.float32))
    return accuracy

def tol_accuracy(y_true, y_pred):
    threshold = 0.1
    difference = tf.abs(tf.subtract(y_true, y_pred)) - threshold
    correct_predictions = tf.where(difference <= 0, True, False)
    accuracy = tf.reduce_mean(tf.cast(correct_predictions, tf.float32))
    return accuracy

def plot_training_results(title,loss,channels_accuracy,notes_accuracy,velocities_accuracy,times_accuracy,val_loss,val_channels_accuracy,val_notes_accuracy,val_velocities_accuracy,val_times_accuracy):
    n = len(loss)+1
    x = range(1,n)
    x_ticks = range(1,n,max(1,n//10))

    plt.figure()
    plt.plot(x, loss, label="Training loss")
    plt.plot(x, val_loss, label="Validation loss")
    plt.title(title)
    plt.legend()
    plt.xlabel("Number of epochs")
    plt.ylabel("Loss")
    plt.xticks(x_ticks)
    plt.show()

    fig, axs = plt.subplots(2, 2, figsize=(9, 8))

    axs[0,0].plot(x, channels_accuracy, label="Training set")
    axs[0,0].plot(x, val_channels_accuracy, label="Validation set")
    axs[0,0].legend()
    axs[0,0].set_ylim([0,1])
    axs[0,0].set_title("Channels")
    axs[0,0].set_xlabel("Number of epochs")
    axs[0,0].set_ylabel("Accuracy")
    axs[0,0].set_xticks(x_ticks)

    axs[0,1].plot(x, notes_accuracy, label="Training set")
    axs[0,1].plot(x, val_notes_accuracy, label="Validation set")
    axs[0,1].legend()
    axs[0,1].set_ylim([0,1])
    axs[0,1].set_title("Notes")
    axs[0,1].set_xlabel("Number of epochs")
    axs[0,1].set_ylabel("Accuracy")
    axs[0,1].set_xticks(x_ticks)

    axs[1,0].plot(x, velocities_accuracy, label="Training set")
    axs[1,0].plot(x, val_velocities_accuracy, label="Validation set")
    axs[1,0].legend()
    axs[1,0].set_ylim([0,1])
    axs[1,0].set_title("Velocity")
    axs[1,0].set_xlabel("Number of epochs")
    axs[1,0].set_ylabel("Accuracy")
    axs[1,0].set_xticks(x_ticks)

    axs[1,1].plot(x, times_accuracy, label="Training set")
    axs[1,1].plot(x, val_times_accuracy, label="Validation set")
    axs[1,1].legend()
    axs[1,1].set_ylim([0,1])
    axs[1,1].set_title("Time")
    axs[1,1].set_xlabel("Number of epochs")
    axs[1,1].set_ylabel("Accuracy")
    axs[1,1].set_xticks(x_ticks)

    fig.suptitle(title)
    fig.tight_layout(rect=[0, 0, 1, 1])

# %%
seq_length = 30
val_split = 0.1
test_split = 0.1
train_split = 1 - val_split - test_split

total_samples = sum((len(song) - 1) // seq_length for song in ClassicSongs.values())

X_Channels = np.zeros((total_samples, seq_length, n_Channels))
X_Notes = np.zeros((total_samples, seq_length, n_Notes))
X_Velocities = np.zeros((total_samples, seq_length, n_Velocities))
X_Times = np.zeros((total_samples, seq_length, 1))
y_Channels = np.zeros((total_samples, seq_length, n_Channels))
y_Notes = np.zeros((total_samples, seq_length, n_Notes))
y_Velocities = np.zeros((total_samples, seq_length, n_Velocities))
y_Times = np.zeros((total_samples, seq_length, 1))

current_index = 0
for song in ClassicSongs.values():
    song_x_channels, song_y_channels = pp.label_sequences(pp.one_hot_encode(channel_to_ind, song[:, 0]), seq_length)
    song_x_notes, song_y_notes = pp.label_sequences(pp.one_hot_encode(note_to_ind, song[:, 1]), seq_length)
    song_x_velocities, song_y_velocities = pp.label_sequences(pp.one_hot_encode(velocity_to_ind, song[:, 2]), seq_length)
    song_x_ticks, song_y_ticks = pp.label_sequences(song[:, 3:], seq_length)
    
    n_samples = song_x_channels.shape[0]
    next_index = current_index + n_samples
    
    X_Channels[current_index:next_index] = song_x_channels
    X_Notes[current_index:next_index] = song_x_notes
    X_Velocities[current_index:next_index] = song_x_velocities
    X_Times[current_index:next_index] = song_x_ticks
    y_Channels[current_index:next_index] = song_y_channels
    y_Notes[current_index:next_index] = song_y_notes
    y_Velocities[current_index:next_index] = song_y_velocities
    y_Times[current_index:next_index] = song_y_ticks
    
    current_index = next_index

n_val = int(total_samples*val_split)
n_test = int(total_samples*test_split)
indices = np.random.permutation(total_samples)
val_indices = indices[:n_val]
test_indices = indices[-n_test:]
train_indices = indices[n_val:-n_test]

Test_X_Channels = X_Channels[test_indices,:,:]
Test_X_Notes = X_Notes[test_indices,:,:]
Test_X_Velocities = X_Velocities[test_indices,:,:]
Test_X_Times = X_Times[test_indices,:,:]
Test_y_Channels = y_Channels[test_indices,:,:]
Test_y_Notes = y_Notes[test_indices,:,:]
Test_y_Velocities = y_Velocities[test_indices,:,:]
Test_y_Times = y_Times[test_indices,:,:]

Val_X_Channels = X_Channels[val_indices,:,:]
Val_X_Notes = X_Notes[val_indices,:,:]
Val_X_Velocities = X_Velocities[val_indices,:,:]
Val_X_Times = X_Times[val_indices,:,:]
Val_y_Channels = y_Channels[val_indices,:,:]
Val_y_Notes = y_Notes[val_indices,:,:]
Val_y_Velocities = y_Velocities[val_indices,:,:]
Val_y_Times = y_Times[val_indices,:,:]

X_Channels = X_Channels[train_indices,:,:]
X_Notes = X_Notes[train_indices,:,:]
X_Velocities = X_Velocities[train_indices,:,:]
X_Times = X_Times[train_indices,:,:]
y_Channels = y_Channels[train_indices,:,:]
y_Notes = y_Notes[train_indices,:,:]
y_Velocities = y_Velocities[train_indices,:,:]
y_Times = y_Times[train_indices,:,:]


del song_x_channels, song_y_channels, song_x_notes, song_y_notes, song_x_velocities, song_y_velocities, song_x_ticks, song_y_ticks
del dataset, ClassicSongs
gc.collect()
# Out:
# 0

# %%
def create_model(modelType,dim):
    # Define input layer
    input_channels = Input(shape=(None, n_Channels))
    input_notes = Input(shape=(None, n_Notes))
    input_velocities = Input(shape=(None, n_Velocities))
    input_times = Input(shape=(None, 1))

    # Define main layer
    if modelType=="RNN" : output = SimpleRNN(units=dim, return_sequences=True)(concatenate([input_channels, input_notes, input_velocities, input_times]))
    elif modelType=="LSTM" : output = LSTM(units=dim, return_sequences=True)(concatenate([input_channels, input_notes, input_velocities, input_times]))
    elif modelType=="LSTM2":
        hidden = LSTM(units=dim[0], return_sequences=True)(concatenate([input_channels, input_notes, input_velocities, input_times]))
        output = LSTM(units=dim[1], return_sequences=True)(hidden)
        
    # Define Dense layer for each branch
    channels_output = Dense(units=n_Channels)(output)
    notes_output = Dense(units=n_Notes)(output)
    velocities_output = Dense(units=n_Velocities)(output)
    times_output = Dense(units=1)(output)

    # Use Lambda layer to split the output into two branches
    final_channels = Softmax(name="Channels")(channels_output)
    final_notes = Softmax(name="Notes")(notes_output)
    final_velocities = Softmax(name="Velocities")(velocities_output)
    final_times = Lambda(lambda x: (tf.sigmoid(x) * (time_range[1] - time_range[0]) + time_range[0]), name="Times")(times_output)

    # Define the model with inputs and outputs
    return Model(inputs=[input_channels, input_notes, input_velocities, input_times], outputs=[final_channels, final_notes, final_velocities, final_times], name=modelType+"_model")

# %%
dim = 250
n_batch = 200
learning_rate = 0.001

optimizer = optimizers.Adam(learning_rate=learning_rate)

lossesRNN = {
    'Channels': 'categorical_crossentropy',
    'Notes': 'categorical_crossentropy',
    'Velocities': 'categorical_crossentropy',
    'Times': 'mean_squared_error'
}


loss_weightsRNN = {
    'Channels': 0.25,
    'Notes': 5.0,
    'Velocities': 1.0,
    'Times': 1e-6
}

metricsRNN = {
    'Channels': 'accuracy',
    'Notes': 'accuracy',
    'Velocities': 'accuracy',
    'Times': tol_accuracy
}

RNN_model = create_model("RNN",dim)
RNN_model.summary()
RNN_model.compile(optimizer=optimizer, loss=lossesRNN, loss_weights=loss_weightsRNN, metrics=metricsRNN)

lossRNN = []
channels_accuracyRNN = []
notes_accuracyRNN = []
velocities_accuracyRNN = []
times_accuracyRNN = []

val_lossRNN = []
val_channels_accuracyRNN = []
val_notes_accuracyRNN = []
val_velocities_accuracyRNN = []
val_times_accuracyRNN = []
# Out:
# Model: "RNN_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, 12)]   0           []
#
#  input_2 (InputLayer)           [(None, None, 105)]  0           []
#
#  input_3 (InputLayer)           [(None, None, 128)]  0           []
#
#  input_4 (InputLayer)           [(None, None, 1)]    0           []
#
#  concatenate (Concatenate)      (None, None, 246)    0           ['input_1[0][0]',
#                                                                   'input_2[0][0]',
#                                                                   'input_3[0][0]',
#                                                                   'input_4[0][0]']
#
#  simple_rnn (SimpleRNN)         (None, None, 250)    124250      ['concatenate[0][0]']
#
#  dense (Dense)                  (None, None, 12)     3012        ['simple_rnn[0][0]']
#
#  dense_1 (Dense)                (None, None, 105)    26355       ['simple_rnn[0][0]']
#
#  dense_2 (Dense)                (None, None, 128)    32128       ['simple_rnn[0][0]']
#
#  dense_3 (Dense)                (None, None, 1)      251         ['simple_rnn[0][0]']
#
#  Channels (Softmax)             (None, None, 12)     0           ['dense[0][0]']
#
#  Notes (Softmax)                (None, None, 105)    0           ['dense_1[0][0]']
#
#  Velocities (Softmax)           (None, None, 128)    0           ['dense_2[0][0]']
#
#  Times (Lambda)                 (None, None, 1)      0           ['dense_3[0][0]']
#
# ==================================================================================================
# Total params: 185,996
# Trainable params: 185,996
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
n_epochs = 20

history = RNN_model.fit([X_Channels, X_Notes, X_Velocities, X_Times], [y_Channels, y_Notes, y_Velocities, y_Times], epochs=n_epochs, batch_size=n_batch, validation_data=([Val_X_Channels, Val_X_Notes, Val_X_Velocities, Val_X_Times], [Val_y_Channels, Val_y_Notes, Val_y_Velocities, Val_y_Times]))

lossRNN += history.history['loss']
channels_accuracyRNN += history.history['Channels_accuracy']
notes_accuracyRNN += history.history['Notes_accuracy']
velocities_accuracyRNN += history.history['Velocities_accuracy']
times_accuracyRNN += history.history['Times_tol_accuracy']

val_lossRNN += history.history['val_loss']
val_channels_accuracyRNN += history.history['val_Channels_accuracy']
val_notes_accuracyRNN += history.history['val_Notes_accuracy']
val_velocities_accuracyRNN += history.history['val_Velocities_accuracy']
val_times_accuracyRNN += history.history['val_Times_tol_accuracy']
# Out:
# Epoch 1/20
# 284/284 [==============================] - 40s 115ms/step - loss: 20.1945 - Channels_loss: 0.7177 - Notes_loss: 3.5298 - Velocities_loss: 2.3657 - Times_loss: 442.7570 - Channels_accuracy: 0.7091 - Notes_accuracy: 0.1069 - Velocities_accuracy: 0.5901 - Times_tol_accuracy: 9.3897e-06 - val_loss: 18.1624 - val_Channels_loss: 0.6102 - val_Notes_loss: 3.1710 - val_Velocities_loss: 2.1547 - val_Times_loss: 78.0706 - val_Channels_accuracy: 0.7287 - val_Notes_accuracy: 0.1583 - val_Velocities_accuracy: 0.6107 - val_Times_tol_accuracy: 1.8519e-05
# Epoch 2/20
# 284/284 [==============================] - 31s 108ms/step - loss: 17.6984 - Channels_loss: 0.5661 - Notes_loss: 3.1036 - Velocities_loss: 2.0386 - Times_loss: 46.1974 - Channels_accuracy: 0.7383 - Notes_accuracy: 0.1732 - Velocities_accuracy: 0.6161 - Times_tol_accuracy: 6.7034e-05 - val_loss: 17.3625 - val_Channels_loss: 0.5341 - val_Notes_loss: 3.0559 - val_Velocities_loss: 1.9495 - val_Times_loss: 27.5461 - val_Channels_accuracy: 0.7531 - val_Notes_accuracy: 0.1854 - val_Velocities_accuracy: 0.6181 - val_Times_tol_accuracy: 1.3889e-04
# Epoch 3/20
# 284/284 [==============================] - 30s 107ms/step - loss: 17.1552 - Channels_loss: 0.5283 - Notes_loss: 3.0270 - Velocities_loss: 1.8881 - Times_loss: 20.8393 - Channels_accuracy: 0.7524 - Notes_accuracy: 0.1907 - Velocities_accuracy: 0.6210 - Times_tol_accuracy: 1.3592e-04 - val_loss: 17.0319 - val_Channels_loss: 0.5155 - val_Notes_loss: 3.0106 - val_Velocities_loss: 1.8500 - val_Times_loss: 13.2824 - val_Channels_accuracy: 0.7586 - val_Notes_accuracy: 0.1953 - val_Velocities_accuracy: 0.6223 - val_Times_tol_accuracy: 2.2222e-04
# Epoch 4/20
# 284/284 [==============================] - 31s 109ms/step - loss: 16.8625 - Channels_loss: 0.5140 - Notes_loss: 2.9839 - Velocities_loss: 1.8147 - Times_loss: 12.3928 - Channels_accuracy: 0.7568 - Notes_accuracy: 0.1996 - Velocities_accuracy: 0.6243 - Times_tol_accuracy: 3.6949e-04 - val_loss: 16.7860 - val_Channels_loss: 0.5061 - val_Notes_loss: 2.9733 - val_Velocities_loss: 1.7931 - val_Times_loss: 11.6085 - val_Channels_accuracy: 0.7628 - val_Notes_accuracy: 0.2018 - val_Velocities_accuracy: 0.6257 - val_Times_tol_accuracy: 3.5185e-04
# Epoch 5/20
# 284/284 [==============================] - 32s 112ms/step - loss: 16.6591 - Channels_loss: 0.5064 - Notes_loss: 2.9516 - Velocities_loss: 1.7743 - Times_loss: 8.7462 - Channels_accuracy: 0.7604 - Notes_accuracy: 0.2065 - Velocities_accuracy: 0.6279 - Times_tol_accuracy: 0.0011 - val_loss: 16.6154 - val_Channels_loss: 0.5033 - val_Notes_loss: 2.9438 - val_Velocities_loss: 1.7705 - val_Times_loss: 8.5327 - val_Channels_accuracy: 0.7662 - val_Notes_accuracy: 0.2073 - val_Velocities_accuracy: 0.6291 - val_Times_tol_accuracy: 0.0013
# Epoch 6/20
# 284/284 [==============================] - 31s 108ms/step - loss: 16.4982 - Channels_loss: 0.4997 - Notes_loss: 2.9247 - Velocities_loss: 1.7496 - Times_loss: 6.5814 - Channels_accuracy: 0.7633 - Notes_accuracy: 0.2118 - Velocities_accuracy: 0.6307 - Times_tol_accuracy: 0.0029 - val_loss: 16.5115 - val_Channels_loss: 0.4928 - val_Notes_loss: 2.9282 - val_Velocities_loss: 1.7472 - val_Times_loss: 5.7613 - val_Channels_accuracy: 0.7668 - val_Notes_accuracy: 0.2115 - val_Velocities_accuracy: 0.6314 - val_Times_tol_accuracy: 0.0051
# Epoch 7/20
# 284/284 [==============================] - 31s 108ms/step - loss: 16.3610 - Channels_loss: 0.4944 - Notes_loss: 2.9008 - Velocities_loss: 1.7333 - Times_loss: 5.0934 - Channels_accuracy: 0.7656 - Notes_accuracy: 0.2168 - Velocities_accuracy: 0.6326 - Times_tol_accuracy: 0.0066 - val_loss: 16.3837 - val_Channels_loss: 0.4910 - val_Notes_loss: 2.9052 - val_Velocities_loss: 1.7351 - val_Times_loss: 4.7260 - val_Channels_accuracy: 0.7692 - val_Notes_accuracy: 0.2158 - val_Velocities_accuracy: 0.6329 - val_Times_tol_accuracy: 0.0092
# Epoch 8/20
# 284/284 [==============================] - 30s 105ms/step - loss: 16.2437 - Channels_loss: 0.4901 - Notes_loss: 2.8797 - Velocities_loss: 1.7225 - Times_loss: 4.2352 - Channels_accuracy: 0.7675 - Notes_accuracy: 0.2210 - Velocities_accuracy: 0.6339 - Times_tol_accuracy: 0.0133 - val_loss: 16.2876 - val_Channels_loss: 0.4856 - val_Notes_loss: 2.8875 - val_Velocities_loss: 1.7288 - val_Times_loss: 4.2372 - val_Channels_accuracy: 0.7720 - val_Notes_accuracy: 0.2188 - val_Velocities_accuracy: 0.6342 - val_Times_tol_accuracy: 0.0119
# Epoch 9/20
# 284/284 [==============================] - 30s 107ms/step - loss: 16.1424 - Channels_loss: 0.4862 - Notes_loss: 2.8613 - Velocities_loss: 1.7146 - Times_loss: 3.2602 - Channels_accuracy: 0.7696 - Notes_accuracy: 0.2249 - Velocities_accuracy: 0.6350 - Times_tol_accuracy: 0.0257 - val_loss: 16.1932 - val_Channels_loss: 0.4787 - val_Notes_loss: 2.8711 - val_Velocities_loss: 1.7178 - val_Times_loss: 2.3950 - val_Channels_accuracy: 0.7736 - val_Notes_accuracy: 0.2214 - val_Velocities_accuracy: 0.6352 - val_Times_tol_accuracy: 0.0281
# Epoch 10/20
# 284/284 [==============================] - 29s 103ms/step - loss: 16.0447 - Channels_loss: 0.4815 - Notes_loss: 2.8431 - Velocities_loss: 1.7086 - Times_loss: 2.6322 - Channels_accuracy: 0.7716 - Notes_accuracy: 0.2280 - Velocities_accuracy: 0.6358 - Times_tol_accuracy: 0.0414 - val_loss: 16.1187 - val_Channels_loss: 0.4756 - val_Notes_loss: 2.8572 - val_Velocities_loss: 1.7137 - val_Times_loss: 2.3800 - val_Channels_accuracy: 0.7776 - val_Notes_accuracy: 0.2263 - val_Velocities_accuracy: 0.6362 - val_Times_tol_accuracy: 0.0457
# Epoch 11/20
# 284/284 [==============================] - 30s 106ms/step - loss: 15.9625 - Channels_loss: 0.4776 - Notes_loss: 2.8280 - Velocities_loss: 1.7031 - Times_loss: 2.1762 - Channels_accuracy: 0.7739 - Notes_accuracy: 0.2311 - Velocities_accuracy: 0.6365 - Times_tol_accuracy: 0.0638 - val_loss: 16.0453 - val_Channels_loss: 0.4722 - val_Notes_loss: 2.8432 - val_Velocities_loss: 1.7113 - val_Times_loss: 2.5713 - val_Channels_accuracy: 0.7785 - val_Notes_accuracy: 0.2273 - val_Velocities_accuracy: 0.6369 - val_Times_tol_accuracy: 0.0649
# Epoch 12/20
# 284/284 [==============================] - 31s 108ms/step - loss: 15.8827 - Channels_loss: 0.4743 - Notes_loss: 2.8134 - Velocities_loss: 1.6973 - Times_loss: 1.7772 - Channels_accuracy: 0.7765 - Notes_accuracy: 0.2345 - Velocities_accuracy: 0.6372 - Times_tol_accuracy: 0.0878 - val_loss: 15.9651 - val_Channels_loss: 0.4709 - val_Notes_loss: 2.8282 - val_Velocities_loss: 1.7062 - val_Times_loss: 1.5241 - val_Channels_accuracy: 0.7792 - val_Notes_accuracy: 0.2311 - val_Velocities_accuracy: 0.6369 - val_Times_tol_accuracy: 0.0860
# Epoch 13/20
# 284/284 [==============================] - 31s 108ms/step - loss: 15.8006 - Channels_loss: 0.4714 - Notes_loss: 2.7980 - Velocities_loss: 1.6928 - Times_loss: 1.3850 - Channels_accuracy: 0.7784 - Notes_accuracy: 0.2375 - Velocities_accuracy: 0.6378 - Times_tol_accuracy: 0.1206 - val_loss: 15.9154 - val_Channels_loss: 0.4672 - val_Notes_loss: 2.8192 - val_Velocities_loss: 1.7025 - val_Times_loss: 1.0706 - val_Channels_accuracy: 0.7829 - val_Notes_accuracy: 0.2343 - val_Velocities_accuracy: 0.6381 - val_Times_tol_accuracy: 0.1579
# Epoch 14/20
# 284/284 [==============================] - 31s 108ms/step - loss: 15.7435 - Channels_loss: 0.4687 - Notes_loss: 2.7873 - Velocities_loss: 1.6897 - Times_loss: 1.1787 - Channels_accuracy: 0.7804 - Notes_accuracy: 0.2400 - Velocities_accuracy: 0.6383 - Times_tol_accuracy: 0.1486 - val_loss: 15.8556 - val_Channels_loss: 0.4644 - val_Notes_loss: 2.8078 - val_Velocities_loss: 1.7004 - val_Times_loss: 1.0470 - val_Channels_accuracy: 0.7840 - val_Notes_accuracy: 0.2365 - val_Velocities_accuracy: 0.6375 - val_Times_tol_accuracy: 0.1934
# Epoch 15/20
# 284/284 [==============================] - 30s 107ms/step - loss: 15.6728 - Channels_loss: 0.4672 - Notes_loss: 2.7741 - Velocities_loss: 1.6857 - Times_loss: 0.9775 - Channels_accuracy: 0.7815 - Notes_accuracy: 0.2430 - Velocities_accuracy: 0.6390 - Times_tol_accuracy: 0.1834 - val_loss: 15.7981 - val_Channels_loss: 0.4630 - val_Notes_loss: 2.7973 - val_Velocities_loss: 1.6958 - val_Times_loss: 0.8146 - val_Channels_accuracy: 0.7861 - val_Notes_accuracy: 0.2387 - val_Velocities_accuracy: 0.6382 - val_Times_tol_accuracy: 0.2048
# Epoch 16/20
# 284/284 [==============================] - 30s 107ms/step - loss: 15.6173 - Channels_loss: 0.4649 - Notes_loss: 2.7637 - Velocities_loss: 1.6825 - Times_loss: 0.8064 - Channels_accuracy: 0.7830 - Notes_accuracy: 0.2451 - Velocities_accuracy: 0.6392 - Times_tol_accuracy: 0.2128 - val_loss: 15.7580 - val_Channels_loss: 0.4630 - val_Notes_loss: 2.7898 - val_Velocities_loss: 1.6931 - val_Times_loss: 0.8035 - val_Channels_accuracy: 0.7860 - val_Notes_accuracy: 0.2402 - val_Velocities_accuracy: 0.6385 - val_Times_tol_accuracy: 0.2172
# Epoch 17/20
# 284/284 [==============================] - 30s 107ms/step - loss: 15.5629 - Channels_loss: 0.4634 - Notes_loss: 2.7534 - Velocities_loss: 1.6799 - Times_loss: 0.6814 - Channels_accuracy: 0.7841 - Notes_accuracy: 0.2478 - Velocities_accuracy: 0.6397 - Times_tol_accuracy: 0.2426 - val_loss: 15.7271 - val_Channels_loss: 0.4593 - val_Notes_loss: 2.7842 - val_Velocities_loss: 1.6912 - val_Times_loss: 0.6445 - val_Channels_accuracy: 0.7881 - val_Notes_accuracy: 0.2419 - val_Velocities_accuracy: 0.6394 - val_Times_tol_accuracy: 0.2544
# Epoch 18/20
# 284/284 [==============================] - 31s 108ms/step - loss: 15.5164 - Channels_loss: 0.4617 - Notes_loss: 2.7446 - Velocities_loss: 1.6780 - Times_loss: 0.6252 - Channels_accuracy: 0.7849 - Notes_accuracy: 0.2497 - Velocities_accuracy: 0.6401 - Times_tol_accuracy: 0.2628 - val_loss: 15.6580 - val_Channels_loss: 0.4599 - val_Notes_loss: 2.7708 - val_Velocities_loss: 1.6890 - val_Times_loss: 0.5602 - val_Channels_accuracy: 0.7872 - val_Notes_accuracy: 0.2443 - val_Velocities_accuracy: 0.6395 - val_Times_tol_accuracy: 0.2985
# Epoch 19/20
# 284/284 [==============================] - 31s 108ms/step - loss: 15.4600 - Channels_loss: 0.4596 - Notes_loss: 2.7340 - Velocities_loss: 1.6749 - Times_loss: 0.5062 - Channels_accuracy: 0.7864 - Notes_accuracy: 0.2525 - Velocities_accuracy: 0.6408 - Times_tol_accuracy: 0.2987 - val_loss: 15.6313 - val_Channels_loss: 0.4585 - val_Notes_loss: 2.7651 - val_Velocities_loss: 1.6913 - val_Times_loss: 0.5221 - val_Channels_accuracy: 0.7881 - val_Notes_accuracy: 0.2471 - val_Velocities_accuracy: 0.6398 - val_Times_tol_accuracy: 0.3148
# Epoch 20/20
# 284/284 [==============================] - 31s 109ms/step - loss: 15.4107 - Channels_loss: 0.4577 - Notes_loss: 2.7247 - Velocities_loss: 1.6725 - Times_loss: 0.4341 - Channels_accuracy: 0.7877 - Notes_accuracy: 0.2547 - Velocities_accuracy: 0.6409 - Times_tol_accuracy: 0.3312 - val_loss: 15.5903 - val_Channels_loss: 0.4574 - val_Notes_loss: 2.7575 - val_Velocities_loss: 1.6885 - val_Times_loss: 0.4216 - val_Channels_accuracy: 0.7911 - val_Notes_accuracy: 0.2485 - val_Velocities_accuracy: 0.6403 - val_Times_tol_accuracy: 0.3720

# %%
# %matplotlib qt
plot_training_results("Training our Multi-Input Multi-Output RNN",lossRNN,channels_accuracyRNN,notes_accuracyRNN,velocities_accuracyRNN,times_accuracyRNN,val_lossRNN,val_channels_accuracyRNN,val_notes_accuracyRNN,val_velocities_accuracyRNN,val_times_accuracyRNN)

# %%
dim = 250
n_batch = 200
learning_rate = 0.001

optimizerLSTM = optimizers.Adam(learning_rate=learning_rate)

lossesLSTM = {
    'Channels': 'categorical_crossentropy',
    'Notes': 'categorical_crossentropy',
    'Velocities': 'categorical_crossentropy',
    'Times': 'mean_squared_error'
}


loss_weightsLSTM = {
    'Channels': 0.5,
    'Notes': 5.0,
    'Velocities': 1.0,
    'Times': 2e-7
}

metricsLSTM = {
    'Channels': 'accuracy',
    'Notes': 'accuracy',
    'Velocities': 'accuracy',
    'Times': tol_accuracy
}

LSTM_model = create_model("LSTM",dim)
LSTM_model.summary()
LSTM_model.compile(optimizer=optimizerLSTM, loss=lossesLSTM, loss_weights=loss_weightsLSTM, metrics=metricsLSTM)

lossLSTM = []
channels_accuracyLSTM = []
notes_accuracyLSTM = []
velocities_accuracyLSTM = []
times_accuracyLSTM = []

val_lossLSTM = []
val_channels_accuracyLSTM = []
val_notes_accuracyLSTM = []
val_velocities_accuracyLSTM = []
val_times_accuracyLSTM = []
# Out:
# Model: "RNN_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_13 (InputLayer)          [(None, None, 12)]   0           []
#
#  input_14 (InputLayer)          [(None, None, 105)]  0           []
#
#  input_15 (InputLayer)          [(None, None, 128)]  0           []
#
#  input_16 (InputLayer)          [(None, None, 1)]    0           []
#
#  concatenate_3 (Concatenate)    (None, None, 246)    0           ['input_13[0][0]',
#                                                                   'input_14[0][0]',
#                                                                   'input_15[0][0]',
#                                                                   'input_16[0][0]']
#
#  lstm_2 (LSTM)                  (None, None, 250)    497000      ['concatenate_3[0][0]']
#
#  dense_12 (Dense)               (None, None, 12)     3012        ['lstm_2[0][0]']
#
#  dense_13 (Dense)               (None, None, 105)    26355       ['lstm_2[0][0]']
#
#  dense_14 (Dense)               (None, None, 128)    32128       ['lstm_2[0][0]']
#
#  dense_15 (Dense)               (None, None, 1)      251         ['lstm_2[0][0]']
#
#  Channels (Softmax)             (None, None, 12)     0           ['dense_12[0][0]']
#
#  Notes (Softmax)                (None, None, 105)    0           ['dense_13[0][0]']
#
#  Velocities (Softmax)           (None, None, 128)    0           ['dense_14[0][0]']
#
#  Times (Lambda)                 (None, None, 1)      0           ['dense_15[0][0]']
#
# ==================================================================================================
# Total params: 558,746
# Trainable params: 558,746
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
n_epochs = 20

history = LSTM_model.fit([X_Channels, X_Notes, X_Velocities, X_Times], [y_Channels, y_Notes, y_Velocities, y_Times], epochs=n_epochs, batch_size=n_batch, validation_data=([Val_X_Channels, Val_X_Notes, Val_X_Velocities, Val_X_Times], [Val_y_Channels, Val_y_Notes, Val_y_Velocities, Val_y_Times]))

lossLSTM += history.history['loss']
channels_accuracyLSTM += history.history['Channels_accuracy']
notes_accuracyLSTM += history.history['Notes_accuracy']
velocities_accuracyLSTM += history.history['Velocities_accuracy']
times_accuracyLSTM += history.history['Times_tol_accuracy']

val_lossLSTM += history.history['val_loss']
val_channels_accuracyLSTM += history.history['val_Channels_accuracy']
val_notes_accuracyLSTM += history.history['val_Notes_accuracy']
val_velocities_accuracyLSTM += history.history['val_Velocities_accuracy']
val_times_accuracyLSTM += history.history['val_Times_tol_accuracy']
# Out:
# Epoch 1/20
# 284/284 [==============================] - 87s 276ms/step - loss: 21.2431 - Channels_loss: 0.7414 - Notes_loss: 3.6728 - Velocities_loss: 2.5082 - Times_loss: 500.4359 - Channels_accuracy: 0.7154 - Notes_accuracy: 0.0853 - Velocities_accuracy: 0.5746 - Times_tol_accuracy: 3.9838e-04 - val_loss: 19.0489 - val_Channels_loss: 0.5890 - val_Notes_loss: 3.3047 - val_Velocities_loss: 2.2311 - val_Times_loss: 88.1786 - val_Channels_accuracy: 0.7339 - val_Notes_accuracy: 0.1254 - val_Velocities_accuracy: 0.6081 - val_Times_tol_accuracy: 0.0018
# Epoch 2/20
# 284/284 [==============================] - 71s 250ms/step - loss: 18.3436 - Channels_loss: 0.5577 - Notes_loss: 3.1887 - Velocities_loss: 2.1213 - Times_loss: 45.7824 - Channels_accuracy: 0.7351 - Notes_accuracy: 0.1423 - Velocities_accuracy: 0.6118 - Times_tol_accuracy: 0.0175 - val_loss: 17.8676 - val_Channels_loss: 0.5318 - val_Notes_loss: 3.1139 - val_Velocities_loss: 2.0324 - val_Times_loss: 21.5356 - val_Channels_accuracy: 0.7418 - val_Notes_accuracy: 0.1587 - val_Velocities_accuracy: 0.6111 - val_Times_tol_accuracy: 0.0269
# Epoch 3/20
# 284/284 [==============================] - 71s 250ms/step - loss: 17.5563 - Channels_loss: 0.5165 - Notes_loss: 3.0674 - Velocities_loss: 1.9613 - Times_loss: 12.5393 - Channels_accuracy: 0.7440 - Notes_accuracy: 0.1710 - Velocities_accuracy: 0.6143 - Times_tol_accuracy: 0.0668 - val_loss: 17.3319 - val_Channels_loss: 0.5045 - val_Notes_loss: 3.0331 - val_Velocities_loss: 1.9141 - val_Times_loss: 7.4534 - val_Channels_accuracy: 0.7509 - val_Notes_accuracy: 0.1797 - val_Velocities_accuracy: 0.6135 - val_Times_tol_accuracy: 0.0723
# Epoch 4/20
# 284/284 [==============================] - 72s 252ms/step - loss: 17.1381 - Channels_loss: 0.4974 - Notes_loss: 3.0029 - Velocities_loss: 1.8749 - Times_loss: 5.0737 - Channels_accuracy: 0.7504 - Notes_accuracy: 0.1870 - Velocities_accuracy: 0.6157 - Times_tol_accuracy: 0.0828 - val_loss: 17.0547 - val_Channels_loss: 0.4873 - val_Notes_loss: 2.9911 - val_Velocities_loss: 1.8556 - val_Times_loss: 3.8747 - val_Channels_accuracy: 0.7572 - val_Notes_accuracy: 0.1912 - val_Velocities_accuracy: 0.6152 - val_Times_tol_accuracy: 0.0846
# Epoch 5/20
# 284/284 [==============================] - 70s 246ms/step - loss: 16.8421 - Channels_loss: 0.4841 - Notes_loss: 2.9548 - Velocities_loss: 1.8260 - Times_loss: 2.9504 - Channels_accuracy: 0.7559 - Notes_accuracy: 0.1982 - Velocities_accuracy: 0.6173 - Times_tol_accuracy: 0.0649 - val_loss: 16.7491 - val_Channels_loss: 0.4754 - val_Notes_loss: 2.9395 - val_Velocities_loss: 1.8142 - val_Times_loss: 2.5825 - val_Channels_accuracy: 0.7635 - val_Notes_accuracy: 0.2018 - val_Velocities_accuracy: 0.6171 - val_Times_tol_accuracy: 0.0635
# Epoch 6/20
# 284/284 [==============================] - 69s 245ms/step - loss: 16.5699 - Channels_loss: 0.4730 - Notes_loss: 2.9103 - Velocities_loss: 1.7818 - Times_loss: 2.0634 - Channels_accuracy: 0.7617 - Notes_accuracy: 0.2074 - Velocities_accuracy: 0.6211 - Times_tol_accuracy: 0.0595 - val_loss: 16.5119 - val_Channels_loss: 0.4655 - val_Notes_loss: 2.9019 - val_Velocities_loss: 1.7698 - val_Times_loss: 1.9615 - val_Channels_accuracy: 0.7687 - val_Notes_accuracy: 0.2108 - val_Velocities_accuracy: 0.6230 - val_Times_tol_accuracy: 0.0511
# Epoch 7/20
# 284/284 [==============================] - 69s 244ms/step - loss: 16.3138 - Channels_loss: 0.4632 - Notes_loss: 2.8679 - Velocities_loss: 1.7426 - Times_loss: 1.6104 - Channels_accuracy: 0.7686 - Notes_accuracy: 0.2163 - Velocities_accuracy: 0.6266 - Times_tol_accuracy: 0.0578 - val_loss: 16.2489 - val_Channels_loss: 0.4566 - val_Notes_loss: 2.8570 - val_Velocities_loss: 1.7355 - val_Times_loss: 1.4005 - val_Channels_accuracy: 0.7750 - val_Notes_accuracy: 0.2193 - val_Velocities_accuracy: 0.6277 - val_Times_tol_accuracy: 0.0706
# Epoch 8/20
# 284/284 [==============================] - 69s 244ms/step - loss: 16.0752 - Channels_loss: 0.4538 - Notes_loss: 2.8261 - Velocities_loss: 1.7180 - Times_loss: 1.3610 - Channels_accuracy: 0.7753 - Notes_accuracy: 0.2251 - Velocities_accuracy: 0.6301 - Times_tol_accuracy: 0.0636 - val_loss: 16.0476 - val_Channels_loss: 0.4485 - val_Notes_loss: 2.8209 - val_Velocities_loss: 1.7188 - val_Times_loss: 1.2449 - val_Channels_accuracy: 0.7801 - val_Notes_accuracy: 0.2270 - val_Velocities_accuracy: 0.6309 - val_Times_tol_accuracy: 0.0696
# Epoch 9/20
# 284/284 [==============================] - 69s 242ms/step - loss: 15.8489 - Channels_loss: 0.4459 - Notes_loss: 2.7849 - Velocities_loss: 1.7016 - Times_loss: 1.1663 - Channels_accuracy: 0.7816 - Notes_accuracy: 0.2343 - Velocities_accuracy: 0.6328 - Times_tol_accuracy: 0.0674 - val_loss: 15.8225 - val_Channels_loss: 0.4404 - val_Notes_loss: 2.7801 - val_Velocities_loss: 1.7020 - val_Times_loss: 1.1850 - val_Channels_accuracy: 0.7863 - val_Notes_accuracy: 0.2371 - val_Velocities_accuracy: 0.6333 - val_Times_tol_accuracy: 0.0473
# Epoch 10/20
# 284/284 [==============================] - 71s 249ms/step - loss: 15.6257 - Channels_loss: 0.4373 - Notes_loss: 2.7439 - Velocities_loss: 1.6878 - Times_loss: 1.0882 - Channels_accuracy: 0.7888 - Notes_accuracy: 0.2450 - Velocities_accuracy: 0.6351 - Times_tol_accuracy: 0.0705 - val_loss: 15.6124 - val_Channels_loss: 0.4309 - val_Notes_loss: 2.7415 - val_Velocities_loss: 1.6895 - val_Times_loss: 1.0233 - val_Channels_accuracy: 0.7948 - val_Notes_accuracy: 0.2468 - val_Velocities_accuracy: 0.6352 - val_Times_tol_accuracy: 0.0756
# Epoch 11/20
# 284/284 [==============================] - 69s 243ms/step - loss: 15.4075 - Channels_loss: 0.4294 - Notes_loss: 2.7034 - Velocities_loss: 1.6757 - Times_loss: 1.0067 - Channels_accuracy: 0.7956 - Notes_accuracy: 0.2558 - Velocities_accuracy: 0.6371 - Times_tol_accuracy: 0.0834 - val_loss: 15.4318 - val_Channels_loss: 0.4247 - val_Notes_loss: 2.7077 - val_Velocities_loss: 1.6807 - val_Times_loss: 1.0438 - val_Channels_accuracy: 0.7991 - val_Notes_accuracy: 0.2566 - val_Velocities_accuracy: 0.6377 - val_Times_tol_accuracy: 0.0687
# Epoch 12/20
# 284/284 [==============================] - 68s 239ms/step - loss: 15.2112 - Channels_loss: 0.4227 - Notes_loss: 2.6670 - Velocities_loss: 1.6647 - Times_loss: 0.9417 - Channels_accuracy: 0.7999 - Notes_accuracy: 0.2655 - Velocities_accuracy: 0.6389 - Times_tol_accuracy: 0.0952 - val_loss: 15.2677 - val_Channels_loss: 0.4212 - val_Notes_loss: 2.6776 - val_Velocities_loss: 1.6692 - val_Times_loss: 0.8622 - val_Channels_accuracy: 0.8039 - val_Notes_accuracy: 0.2656 - val_Velocities_accuracy: 0.6388 - val_Times_tol_accuracy: 0.1025
# Epoch 13/20
# 284/284 [==============================] - 68s 241ms/step - loss: 15.0355 - Channels_loss: 0.4175 - Notes_loss: 2.6342 - Velocities_loss: 1.6557 - Times_loss: 0.8737 - Channels_accuracy: 0.8034 - Notes_accuracy: 0.2749 - Velocities_accuracy: 0.6404 - Times_tol_accuracy: 0.1169 - val_loss: 15.1159 - val_Channels_loss: 0.4128 - val_Notes_loss: 2.6495 - val_Velocities_loss: 1.6620 - val_Times_loss: 0.8014 - val_Channels_accuracy: 0.8067 - val_Notes_accuracy: 0.2718 - val_Velocities_accuracy: 0.6413 - val_Times_tol_accuracy: 0.1232
# Epoch 14/20
# 284/284 [==============================] - 70s 246ms/step - loss: 14.8766 - Channels_loss: 0.4133 - Notes_loss: 2.6045 - Velocities_loss: 1.6477 - Times_loss: 0.7879 - Channels_accuracy: 0.8059 - Notes_accuracy: 0.2832 - Velocities_accuracy: 0.6422 - Times_tol_accuracy: 0.1440 - val_loss: 14.9994 - val_Channels_loss: 0.4105 - val_Notes_loss: 2.6273 - val_Velocities_loss: 1.6577 - val_Times_loss: 0.7977 - val_Channels_accuracy: 0.8079 - val_Notes_accuracy: 0.2801 - val_Velocities_accuracy: 0.6417 - val_Times_tol_accuracy: 0.1436
# Epoch 15/20
# 284/284 [==============================] - 71s 249ms/step - loss: 14.7307 - Channels_loss: 0.4096 - Notes_loss: 2.5772 - Velocities_loss: 1.6401 - Times_loss: 0.7079 - Channels_accuracy: 0.8081 - Notes_accuracy: 0.2915 - Velocities_accuracy: 0.6435 - Times_tol_accuracy: 0.1722 - val_loss: 14.8699 - val_Channels_loss: 0.4074 - val_Notes_loss: 2.6035 - val_Velocities_loss: 1.6488 - val_Times_loss: 0.6107 - val_Channels_accuracy: 0.8095 - val_Notes_accuracy: 0.2868 - val_Velocities_accuracy: 0.6438 - val_Times_tol_accuracy: 0.1955
# Epoch 16/20
# 284/284 [==============================] - 69s 243ms/step - loss: 14.5939 - Channels_loss: 0.4064 - Notes_loss: 2.5516 - Velocities_loss: 1.6327 - Times_loss: 0.6298 - Channels_accuracy: 0.8100 - Notes_accuracy: 0.2991 - Velocities_accuracy: 0.6450 - Times_tol_accuracy: 0.2033 - val_loss: 14.7830 - val_Channels_loss: 0.4044 - val_Notes_loss: 2.5877 - val_Velocities_loss: 1.6422 - val_Times_loss: 0.5327 - val_Channels_accuracy: 0.8114 - val_Notes_accuracy: 0.2930 - val_Velocities_accuracy: 0.6456 - val_Times_tol_accuracy: 0.2108
# Epoch 17/20
# 284/284 [==============================] - 68s 238ms/step - loss: 14.4716 - Channels_loss: 0.4040 - Notes_loss: 2.5286 - Velocities_loss: 1.6264 - Times_loss: 0.5756 - Channels_accuracy: 0.8111 - Notes_accuracy: 0.3059 - Velocities_accuracy: 0.6464 - Times_tol_accuracy: 0.2359 - val_loss: 14.6870 - val_Channels_loss: 0.4042 - val_Notes_loss: 2.5696 - val_Velocities_loss: 1.6368 - val_Times_loss: 0.5023 - val_Channels_accuracy: 0.8114 - val_Notes_accuracy: 0.2980 - val_Velocities_accuracy: 0.6464 - val_Times_tol_accuracy: 0.2514
# Epoch 18/20
# 284/284 [==============================] - 69s 245ms/step - loss: 14.3519 - Channels_loss: 0.4017 - Notes_loss: 2.5061 - Velocities_loss: 1.6204 - Times_loss: 0.5073 - Channels_accuracy: 0.8125 - Notes_accuracy: 0.3120 - Velocities_accuracy: 0.6475 - Times_tol_accuracy: 0.2660 - val_loss: 14.5897 - val_Channels_loss: 0.4014 - val_Notes_loss: 2.5516 - val_Velocities_loss: 1.6312 - val_Times_loss: 0.4104 - val_Channels_accuracy: 0.8136 - val_Notes_accuracy: 0.3034 - val_Velocities_accuracy: 0.6477 - val_Times_tol_accuracy: 0.2747
# Epoch 19/20
# 284/284 [==============================] - 69s 244ms/step - loss: 14.2416 - Channels_loss: 0.3994 - Notes_loss: 2.4855 - Velocities_loss: 1.6143 - Times_loss: 0.4436 - Channels_accuracy: 0.8139 - Notes_accuracy: 0.3180 - Velocities_accuracy: 0.6488 - Times_tol_accuracy: 0.3005 - val_loss: 14.5214 - val_Channels_loss: 0.3994 - val_Notes_loss: 2.5387 - val_Velocities_loss: 1.6283 - val_Times_loss: 0.3837 - val_Channels_accuracy: 0.8136 - val_Notes_accuracy: 0.3072 - val_Velocities_accuracy: 0.6484 - val_Times_tol_accuracy: 0.2991
# Epoch 20/20
# 284/284 [==============================] - 70s 246ms/step - loss: 14.1395 - Channels_loss: 0.3974 - Notes_loss: 2.4663 - Velocities_loss: 1.6092 - Times_loss: 0.3960 - Channels_accuracy: 0.8149 - Notes_accuracy: 0.3233 - Velocities_accuracy: 0.6498 - Times_tol_accuracy: 0.3328 - val_loss: 14.4516 - val_Channels_loss: 0.3975 - val_Notes_loss: 2.5262 - val_Velocities_loss: 1.6219 - val_Times_loss: 0.3426 - val_Channels_accuracy: 0.8154 - val_Notes_accuracy: 0.3110 - val_Velocities_accuracy: 0.6502 - val_Times_tol_accuracy: 0.3531

# %%
# %matplotlib qt
plot_training_results("Training our Multi-Input Multi-Output LSTM",lossLSTM,channels_accuracyLSTM,notes_accuracyLSTM,velocities_accuracyLSTM,times_accuracyLSTM,val_lossLSTM,val_channels_accuracyLSTM,val_notes_accuracyLSTM,val_velocities_accuracyLSTM,val_times_accuracyLSTM)

# %%
dims = [200,200]
n_batch = 200
learning_rate = 0.001

optimizerLSTM2 = optimizers.Adam(learning_rate=learning_rate)

lossesLSTM2 = {
    'Channels': 'categorical_crossentropy',
    'Notes': 'categorical_crossentropy',
    'Velocities': 'categorical_crossentropy',
    'Times': 'mean_squared_error'
}


loss_weightsLSTM2 = {
    'Channels': 0.5,
    'Notes': 5.0,
    'Velocities': 1.0,
    'Times': 2e-7
}

metricsLSTM2 = {
    'Channels': 'accuracy',
    'Notes': 'accuracy',
    'Velocities': 'accuracy',
    'Times': tol_accuracy
}

LSTM2_model = create_model("LSTM2",dims)
LSTM2_model.summary()
LSTM2_model.compile(optimizer=optimizerLSTM2, loss=lossesLSTM2, loss_weights=loss_weightsLSTM2, metrics=metricsLSTM2)

lossLSTM2 = []
channels_accuracyLSTM2 = []
notes_accuracyLSTM2 = []
velocities_accuracyLSTM2 = []
times_accuracyLSTM2 = []

val_lossLSTM2 = []
val_channels_accuracyLSTM2 = []
val_notes_accuracyLSTM2 = []
val_velocities_accuracyLSTM2 = []
val_times_accuracyLSTM2 = []
# Out:
# Model: "RNN_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_17 (InputLayer)          [(None, None, 12)]   0           []
#
#  input_18 (InputLayer)          [(None, None, 105)]  0           []
#
#  input_19 (InputLayer)          [(None, None, 128)]  0           []
#
#  input_20 (InputLayer)          [(None, None, 1)]    0           []
#
#  concatenate_4 (Concatenate)    (None, None, 246)    0           ['input_17[0][0]',
#                                                                   'input_18[0][0]',
#                                                                   'input_19[0][0]',
#                                                                   'input_20[0][0]']
#
#  lstm_3 (LSTM)                  (None, None, 200)    357600      ['concatenate_4[0][0]']
#
#  lstm_4 (LSTM)                  (None, None, 200)    320800      ['lstm_3[0][0]']
#
#  dense_16 (Dense)               (None, None, 12)     2412        ['lstm_4[0][0]']
#
#  dense_17 (Dense)               (None, None, 105)    21105       ['lstm_4[0][0]']
#
#  dense_18 (Dense)               (None, None, 128)    25728       ['lstm_4[0][0]']
#
#  dense_19 (Dense)               (None, None, 1)      201         ['lstm_4[0][0]']
#
#  Channels (Softmax)             (None, None, 12)     0           ['dense_16[0][0]']
#
#  Notes (Softmax)                (None, None, 105)    0           ['dense_17[0][0]']
#
#  Velocities (Softmax)           (None, None, 128)    0           ['dense_18[0][0]']
#
#  Times (Lambda)                 (None, None, 1)      0           ['dense_19[0][0]']
#
# ==================================================================================================
# Total params: 727,846
# Trainable params: 727,846
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
n_epochs = 5

history = LSTM2_model.fit([X_Channels, X_Notes, X_Velocities, X_Times], [y_Channels, y_Notes, y_Velocities, y_Times], epochs=n_epochs, batch_size=n_batch, validation_data=([Val_X_Channels, Val_X_Notes, Val_X_Velocities, Val_X_Times], [Val_y_Channels, Val_y_Notes, Val_y_Velocities, Val_y_Times]))

lossLSTM2 += history.history['loss']
channels_accuracyLSTM2 += history.history['Channels_accuracy']
notes_accuracyLSTM2 += history.history['Notes_accuracy']
velocities_accuracyLSTM2 += history.history['Velocities_accuracy']
times_accuracyLSTM2 += history.history['Times_tol_accuracy']

val_lossLSTM2 += history.history['val_loss']
val_channels_accuracyLSTM2 += history.history['val_Channels_accuracy']
val_notes_accuracyLSTM2 += history.history['val_Notes_accuracy']
val_velocities_accuracyLSTM2 += history.history['val_Velocities_accuracy']
val_times_accuracyLSTM2 += history.history['val_Times_tol_accuracy']
# Out:
# Epoch 1/5
# 284/284 [==============================] - 150s 506ms/step - loss: 14.3693 - Channels_loss: 0.4022 - Notes_loss: 2.5024 - Velocities_loss: 1.6564 - Times_loss: 1.3818 - Channels_accuracy: 0.8159 - Notes_accuracy: 0.3115 - Velocities_accuracy: 0.6438 - Times_tol_accuracy: 0.0490 - val_loss: 14.5879 - val_Channels_loss: 0.4015 - val_Notes_loss: 2.5440 - val_Velocities_loss: 1.6673 - val_Times_loss: 1.4410 - val_Channels_accuracy: 0.8165 - val_Notes_accuracy: 0.3035 - val_Velocities_accuracy: 0.6428 - val_Times_tol_accuracy: 0.0469
# Epoch 2/5
# 284/284 [==============================] - 123s 434ms/step - loss: 14.2312 - Channels_loss: 0.3992 - Notes_loss: 2.4766 - Velocities_loss: 1.6486 - Times_loss: 1.2042 - Channels_accuracy: 0.8177 - Notes_accuracy: 0.3191 - Velocities_accuracy: 0.6454 - Times_tol_accuracy: 0.0627 - val_loss: 14.4545 - val_Channels_loss: 0.3974 - val_Notes_loss: 2.5192 - val_Velocities_loss: 1.6600 - val_Times_loss: 1.0183 - val_Channels_accuracy: 0.8177 - val_Notes_accuracy: 0.3110 - val_Velocities_accuracy: 0.6445 - val_Times_tol_accuracy: 0.0772
# Epoch 3/5
# 284/284 [==============================] - 94s 331ms/step - loss: 14.1079 - Channels_loss: 0.3960 - Notes_loss: 2.4536 - Velocities_loss: 1.6419 - Times_loss: 1.0290 - Channels_accuracy: 0.8191 - Notes_accuracy: 0.3255 - Velocities_accuracy: 0.6465 - Times_tol_accuracy: 0.0830 - val_loss: 14.3752 - val_Channels_loss: 0.3968 - val_Notes_loss: 2.5045 - val_Velocities_loss: 1.6545 - val_Times_loss: 1.0697 - val_Channels_accuracy: 0.8191 - val_Notes_accuracy: 0.3160 - val_Velocities_accuracy: 0.6453 - val_Times_tol_accuracy: 0.0769
# Epoch 4/5
# 284/284 [==============================] - 94s 332ms/step - loss: 13.9878 - Channels_loss: 0.3938 - Notes_loss: 2.4311 - Velocities_loss: 1.6356 - Times_loss: 0.9061 - Channels_accuracy: 0.8206 - Notes_accuracy: 0.3319 - Velocities_accuracy: 0.6473 - Times_tol_accuracy: 0.1014 - val_loss: 14.3059 - val_Channels_loss: 0.3946 - val_Notes_loss: 2.4917 - val_Velocities_loss: 1.6502 - val_Times_loss: 0.7859 - val_Channels_accuracy: 0.8188 - val_Notes_accuracy: 0.3202 - val_Velocities_accuracy: 0.6450 - val_Times_tol_accuracy: 0.1196
# Epoch 5/5
# 284/284 [==============================] - 92s 324ms/step - loss: 13.8766 - Channels_loss: 0.3914 - Notes_loss: 2.4103 - Velocities_loss: 1.6295 - Times_loss: 0.7896 - Channels_accuracy: 0.8218 - Notes_accuracy: 0.3375 - Velocities_accuracy: 0.6483 - Times_tol_accuracy: 0.1269 - val_loss: 14.2367 - val_Channels_loss: 0.3907 - val_Notes_loss: 2.4790 - val_Velocities_loss: 1.6465 - val_Times_loss: 0.7445 - val_Channels_accuracy: 0.8209 - val_Notes_accuracy: 0.3226 - val_Velocities_accuracy: 0.6466 - val_Times_tol_accuracy: 0.1396

# %%
n = len(lossRNN)+1
x = range(1,n)
x_ticks = range(1,n,max(1,n//10))

plt.figure()
plt.plot(x, lossRNN, label="RNN Training loss",color='red')
plt.plot(x, val_lossRNN, label="RNN Validation loss",color='firebrick')
plt.plot(x, lossLSTM, label="LSTM Training loss",color='blue')
plt.plot(x, val_lossLSTM, label="LSTM Validation loss",color='mediumblue')
plt.plot(x, lossLSTM2, label="2L LSTM Training loss",color='lawngreen')
plt.plot(x, val_lossLSTM2, label="2L LSTM Validation loss",color='forestgreen')
plt.title("Comparison RNN - LSTM")
plt.legend()
plt.xlabel("Number of epochs")
plt.ylabel("Loss")
plt.xticks(x_ticks)
plt.show()

fig, axs = plt.subplots(2, 2, figsize=(9, 8))

axs[0,0].plot(x, channels_accuracyRNN, label="RNN Training set",color='red')
axs[0,0].plot(x, val_channels_accuracyRNN, label="RNN Validation set",color='firebrick')
axs[0,0].plot(x, channels_accuracyLSTM, label="LSTM Training set",color='blue')
axs[0,0].plot(x, val_channels_accuracyLSTM, label="LSTM Validation set",color='mediumblue')
axs[0,0].plot(x, channels_accuracyLSTM2, label="2L LSTM Training set",color='lawngreen')
axs[0,0].plot(x, val_channels_accuracyLSTM2, label="2L LSTM Validation set",color='forestgreen')
axs[0,0].legend()
#axs[0,0].set_ylim([0,1])
axs[0,0].set_title("Channels")
axs[0,0].set_xlabel("Number of epochs")
axs[0,0].set_ylabel("Accuracy")
axs[0,0].set_xticks(x_ticks)

axs[0,1].plot(x, notes_accuracyRNN, label="RNN Training set",color='red')
axs[0,1].plot(x, val_notes_accuracyRNN, label="RNN Validation set",color='firebrick')
axs[0,1].plot(x, notes_accuracyLSTM, label="LSTM Training set",color='blue')
axs[0,1].plot(x, val_notes_accuracyLSTM, label="LSTM Validation set",color='mediumblue')
axs[0,1].plot(x, notes_accuracyLSTM2, label="2L LSTM Training set",color='lawngreen')
axs[0,1].plot(x, val_notes_accuracyLSTM2, label="2L LSTM Validation set",color='forestgreen')
axs[0,1].legend()
#axs[0,1].set_ylim([0,1])
axs[0,1].set_title("Notes")
axs[0,1].set_xlabel("Number of epochs")
axs[0,1].set_ylabel("Accuracy")
axs[0,1].set_xticks(x_ticks)

axs[1,0].plot(x, velocities_accuracyRNN, label="RNN Training set",color='red')
axs[1,0].plot(x, val_velocities_accuracyRNN, label="RNN Validation set",color='firebrick')
axs[1,0].plot(x, velocities_accuracyLSTM, label="LSTM Training set",color='blue')
axs[1,0].plot(x, val_velocities_accuracyLSTM, label="LSTM Validation set",color='mediumblue')
axs[1,0].plot(x, velocities_accuracyLSTM2, label="2L LSTM Training set",color='lawngreen')
axs[1,0].plot(x, val_velocities_accuracyLSTM2, label="2L LSTM Validation set",color='forestgreen')
axs[1,0].legend()
#axs[1,0].set_ylim([0,1])
axs[1,0].set_title("Velocity")
axs[1,0].set_xlabel("Number of epochs")
axs[1,0].set_ylabel("Accuracy")
axs[1,0].set_xticks(x_ticks)

axs[1,1].plot(x, times_accuracyRNN, label="RNN Training set",color='red')
axs[1,1].plot(x, val_times_accuracyRNN, label="RNN Validation set",color='firebrick')
axs[1,1].plot(x, times_accuracyLSTM, label="LSTM Training set",color='blue')
axs[1,1].plot(x, val_times_accuracyLSTM, label="LSTM Validation set",color='mediumblue')
axs[1,1].plot(x, times_accuracyLSTM2, label="2L LSTM Training set",color='lawngreen')
axs[1,1].plot(x, val_times_accuracyLSTM2, label="2L LSTM Validation set",color='forestgreen')
axs[1,1].legend()
#axs[1,1].set_ylim([0,1])
axs[1,1].set_title("Time")
axs[1,1].set_xlabel("Number of epochs")
axs[1,1].set_ylabel("Accuracy")
axs[1,1].set_xticks(x_ticks)

fig.suptitle("Comparison RNN - LSTM")
fig.tight_layout(rect=[0, 0, 1, 1])

# %%
def sample_probas(vec, mode, T):
    output = []
    if mode == "Max":
        channels = np.zeros_like(vec[0])
        i = np.argmax(vec[0][0,0,:])
        channels[0,0,i] = 1
        output += [channels]
        
        notes = np.zeros_like(vec[1])
        i = np.argmax(vec[1][0,0,:])
        notes[0,0,i] = 1
        output += [notes]
    
    elif mode == "Original":
        p = vec[0][0,0,:]
        channels = np.zeros_like(vec[0])
        i = np.random.choice(range(len(p)),p=p)
        channels[0,0,i] = 1
        output += [channels]
        
        p = vec[1][0,0,:]
        notes = np.zeros_like(vec[1])
        i = np.random.choice(range(len(p)),p=p)
        notes[0,0,i] = 1
        output += [notes]
    
    elif mode == "SoftMax":
        q = np.log(vec[0][0,0,:])
        p = np.exp((q - np.max(q))/T)
        p = p/np.sum(p)
        channels = np.zeros_like(vec[0])
        i = np.random.choice(range(len(p)),p=p)
        channels[0,0,i] = 1
        output += [channels]
        
        q = np.log(vec[1][0,0,:])
        p = np.exp((q - np.max(q))/T)
        p = p/np.sum(p)
        notes = np.zeros_like(vec[1])
        i = np.random.choice(range(len(p)),p=p)
        notes[0,0,i] = 1
        output += [notes]
        
    elif mode == "NucleusSampling":
        p = vec[0][0,0,:]
        sorted_p = np.sort(p)[::-1]
        cum_p = np.cumsum(sorted_p)
        k = np.sum(cum_p < T) + 1
        indices = np.argsort(p)[:-k]
        p[indices] = 0
        i = np.random.choice(range(len(p)),p=p/cum_p[k-1])
        channels = np.zeros_like(vec[0])
        channels[0,0,i] = 1
        output += [channels]
        
        p = vec[1][0,0,:]
        sorted_p = np.sort(p)[::-1]
        cum_p = np.cumsum(sorted_p)
        k = np.sum(cum_p < T) + 1
        indices = np.argsort(p)[:-k]
        p[indices] = 0
        i = np.random.choice(range(len(p)),p=p/cum_p[k-1])
        notes = np.zeros_like(vec[1])
        notes[0,0,i] = 1
        output += [notes]
        
    output += [np.rint(vec[2]).astype(int)]
    output += [vec[3]]
    return output

def generate(model,input_vec,output_length,mode="Max",T=1,one_hot=False,reset=False):
    stateful = model.stateful
    model.stateful = True
    if reset : model.reset_states()
    temp_vec = model.predict(input_vec)
    for i in range(4):
        temp_vec[i] = temp_vec[i][:,-1:,:]
    temp_vec = sample_probas(temp_vec,mode,T)
    if one_hot :
        output_vec = temp_vec
    else :
        output_vec = [[ind_to_channel[np.argmax(temp_vec[0][0,0,:])],ind_to_note[np.argmax(temp_vec[1][0,0,:])],temp_vec[2][0,0,0],temp_vec[3][0,0,0]]]
    for i in range(output_length-1):
        temp_vec = model.predict(temp_vec)
        temp_vec = sample_probas(temp_vec,mode,T)
        if one_hot :
            for j in range(4):
                output_vec[j] = np.concatenate((output_vec[j],temp_vec[j]),axis=1)
        else :
            output_vec += [[ind_to_channel[np.argmax(temp_vec[0][0,0,:])],ind_to_note[np.argmax(temp_vec[1][0,0,:])],temp_vec[2][0,0,0],temp_vec[3][0,0,0]]]
    model.stateful = stateful
    return output_vec
    


#LSTM_model.predict([X_Channels[0:1,0:1,:], X_notes[0:1,0:1,:], X_velocities[0:1,0:1,:], X_times[0:1,0:1,:]])
gen = generate(RNN_model,[X_Channels[2:3,:,:], X_Notes[2:3,:,:], X_Velocities[2:3,:,:], X_Times[2:3,:,:]],30,mode="SoftMax",T=0.8)
gen
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11760\1568797848.py in <module>
#      95
#      96 #LSTM_model.predict([X_Channels[0:1,0:1,:], X_notes[0:1,0:1,:], X_velocities[0:1,0:1,:], X_times[0:1,0:1,:]])
# ---> 97 gen = generate(RNN_model,[X_Channels[2:3,:,:], X_Notes[2:3,:,:], X_Velocities[2:3,:,:], X_Times[2:3,:,:]],30,mode="SoftMax",T=0.8)
#      98 gen
#
# NameError: name 'RNN_model' is not defined

# %%
def create_midi(gen):
    channels = []
    notes = []
    velocities = []
    times = []
    for i in range(len(gen)):
        channels += [gen[i][0]]
        notes += [gen[i][1]]
        velocities += [gen[i][2]]
        times += [gen[i][3]]
    return channels, notes, velocities, times

# %%
channels,notes,velocities,times = create_midi(gen)
print(channels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11760\2646984516.py in <module>
# ----> 1 channels,notes,velocities,times = create_midi(gen)
#       2 print(channels)
#
# NameError: name 'gen' is not defined
